# %% [markdown]
# ### Week 3
#
# - Tidy Data
# - Pivot & Melt
# - Difference Between Pivot and Pivot Table
# - Merging Data Frames

# %% [markdown]
# ## Tidy Data

# %% [markdown]
# * each row is a single observation,
# * each column is a single variable, and
# * each value is a single cell (i.e., its entry in the data frame is not shared with another value).

# %% [markdown]
# - The concept stems from a paper written by Hadley Wickham in 2014.
#
# - We tidy our data to create a standard across multiple analysis tools.

# %% [markdown]
# ![](https://datasciencebook.ca/_main_files/figure-html/02-tidy-image-1.png)

# %% [markdown]
# ## What to do when data is not tidy...

# %% [markdown]
# Data sometimes comes in tables that are easy to read/make sense for humans.
#
# They are not necessarily the best format for computers. Sometimes they can also not provide the information very straight forward.
#
# ## Wide to Long

# %% [markdown]
# ## Goal

# %% [markdown]
# ![](https://datasciencebook.ca/img/pivot_functions/pivot_functions.001.jpeg)

# %% [markdown]
# ## Discussion
#
# Why do we do this?
#
# - Looking at the table, which city has the largest population and in what year was it?

# %% [markdown]
# What do you think we could do to make it even easier to find?

# %% [markdown]
# ## From long to wide

# %% [markdown]
# ![](https://datasciencebook.ca/img/pivot_functions/pivot_functions.002.jpeg)

# %% [markdown]
# ### How to Manipulate Long and Wide Tables In Python

# %% [markdown]
# ### Melt
#
# > wide to long format
#
# [Documentation](https://pandas.pydata.org/docs/reference/api/pandas.melt.html)
#
# ![](https://pandas.pydata.org/docs/_images/reshaping_melt.png)

# %%
import pandas as pd

cereal = pd.read_csv('https://raw.githubusercontent.com/UBC-MDS/programming-in-python-for-data-science/master/data/cereal.csv')
cereal = cereal.drop(labels=['type', 'shelf', 'weight', 'cups', 'rating'], axis=1)
cereal.head()
# Out:
#                         name mfr  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N        70        4    1     130   10.0
# 1          100% Natural Bran   Q       120        3    5      15    2.0
# 2                   All-Bran   K        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K        50        4    0     140   14.0
# 4             Almond Delight   R       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins
# 0    5.0       6     280        25
# 1    8.0       8     135         0
# 2    7.0       5     320        25
# 3    8.0       0     330        25
# 4   14.0       8       1        25

# %%
cereal[cereal['name'] == '100% Bran']
# Out:
#         name mfr  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 0  100% Bran   N        70        4    1     130   10.0    5.0       6
#
#    potass  vitamins
# 0     280        25

# %%
cereal_long = cereal.melt(id_vars=['name', 'mfr'])
cereal_long[cereal_long['name'] == '100% Bran']
# Out:
#           name mfr  variable  value
# 0    100% Bran   N  calories   70.0
# 77   100% Bran   N   protein    4.0
# 154  100% Bran   N       fat    1.0
# 231  100% Bran   N    sodium  130.0
# 308  100% Bran   N     fiber   10.0
# 385  100% Bran   N     carbo    5.0
# 462  100% Bran   N    sugars    6.0
# 539  100% Bran   N    potass  280.0
# 616  100% Bran   N  vitamins   25.0

# %% [markdown]
# ### Pivot
#
# > long to wide
#
# [Documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pivot.html)
#
#
# ![](https://pandas.pydata.org/docs/_images/reshaping_pivot.png)

# %%
lego = pd.read_csv('https://raw.githubusercontent.com/UBC-MDS/programming-in-python-for-data-science/master/data/lego_untidy.csv')
lego.head()
# Out:
#   set_num                          name  year  lego_info  value
# 0    00-1               Weetabix Castle  1970   theme_id    414
# 1    00-1               Weetabix Castle  1970  num_parts    471
# 2    00-2  Weetabix Promotional House 1  1976  num_parts    147
# 3    00-2  Weetabix Promotional House 1  1976   theme_id    413
# 4    00-3  Weetabix Promotional House 2  1976  num_parts    149

# %%
lego_tidy = lego.pivot(index='set_num',
                       columns='lego_info',
                       values='value')
lego_tidy.head()
# Out:
# lego_info  num_parts  theme_id
# set_num
# 00-1             471       414
# 00-2             147       413
# 00-3             149       413
# 00-4             126       413
# 00-6               3        67

# %%
lego_tidy = lego.pivot(index=['set_num', 'name'],
                       columns='lego_info',
                       values='value')
lego_tidy.head()
# Out:
# lego_info                              num_parts  theme_id
# set_num name
# 00-1    Weetabix Castle                      471       414
# 00-2    Weetabix Promotional House 1         147       413
# 00-3    Weetabix Promotional House 2         149       413
# 00-4    Weetabix Promotional Windmill        126       413
# 00-6    Special Offer                          3        67

# %%
lego_tidy2 = lego_tidy.reset_index()
lego_tidy2
# Out:
# lego_info       set_num                                 name  num_parts  \
# 0                  00-1                      Weetabix Castle        471
# 1                  00-2         Weetabix Promotional House 1        147
# 2                  00-3         Weetabix Promotional House 2        149
# 3                  00-4        Weetabix Promotional Windmill        126
# 4                  00-6                        Special Offer          3
# ...                 ...                                  ...        ...
# 11668      tominifigs-1            Town Minifig Packs 2-Pack          2
# 11669        trucapam-1               Captain America Mosaic         71
# 11670          tsuper-1                    Technic Super Set          3
# 11671           vwkit-1                       Volkswagen Kit         22
# 11672           wwgp1-1  Wild West Limited Edition Gift Pack          3
#
# lego_info  theme_id
# 0               414
# 1               413
# 2               413
# 3               413
# 4                67
# ...             ...
# 11668            50
# 11669           598
# 11670            12
# 11671           366
# 11672           476
#
# [11673 rows x 4 columns]

# %%
# What if I want to use the name?
lego.pivot(index='name',
           columns='lego_info',
           values='value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 # What if I want to use the name?
# ----> 2 lego.pivot(index='name',
#       3            columns='lego_info',
#       4            values='value')
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:7876, in DataFrame.pivot(self, index, columns, values)
#    7871 @Substitution("")
#    7872 @Appender(_shared_docs["pivot"])
#    7873 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7874     from pandas.core.reshape.pivot import pivot
# -> 7876     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/reshape/pivot.py:520, in pivot(data, index, columns, values)
#     518     else:
#     519         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520 return indexed.unstack(columns_listlike)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/series.py:4157, in Series.unstack(self, level, fill_value)
#    4114 """
#    4115 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4116
#    (...)
#    4153 b    2    4
#    4154 """
#    4155 from pandas.core.reshape.reshape import unstack
# -> 4157 return unstack(self, level, fill_value)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:491, in unstack(obj, level, fill_value)
#     489 if is_1d_only_ea_dtype(obj.dtype):
#     490     return _unstack_extension_series(obj, level, fill_value)
# --> 491 unstacker = _Unstacker(
#     492     obj.index, level=level, constructor=obj._constructor_expanddim
#     493 )
#     494 return unstacker.get_result(
#     495     obj._values, value_columns=None, fill_value=fill_value
#     496 )
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:140, in _Unstacker.__init__(self, index, level, constructor)
#     133 if num_cells > np.iinfo(np.int32).max:
#     134     warnings.warn(
#     135         f"The following operation may generate {num_cells} cells "
#     136         f"in the resulting pandas object.",
#     137         PerformanceWarning,
#     138     )
# --> 140 self._make_selectors()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:192, in _Unstacker._make_selectors(self)
#     189 mask.put(selector, True)
#     191 if mask.sum() < len(self.index):
# --> 192     raise ValueError("Index contains duplicate entries, cannot reshape")
#     194 self.group_index = comp_index
#     195 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
lego_tidy3 = lego.pivot_table(index=['name', 'set_num'],
           columns='lego_info',
           values='value')
lego_tidy3
# Out:
# lego_info                                   num_parts  theme_id
# name                             set_num
#  1 stud Blue Storage Brick       5003565-1          0       501
#  Scenery and Dagger Trap polybag 5002919-1         25       435
#  Spectre                         71010-7            7       552
#  White Spaceman Key Chain        852815-1           0       503
# 'Where Are My Pants?' Guy        71004-13           6       549
# ...                                               ...       ...
# {Red Race Car Number 3}          1477-1            39        82
# {Roadplates and Scenery}         9360-1            85       533
# {Rock Saw Vehicle}               1275-1            22       442
# {Town Vehicles}                  1062-1           158       533
# {Yellow Cab}                     40025-1           44        22
#
# [11673 rows x 2 columns]

# %%
lego_tidy3.reset_index().value_counts('name')
# Out:
# name
# Basic Building Set                                     55
# Universal Building Set                                 32
# Helicopter                                             23
# Basic Set                                              23
# Fire Station                                           14
#                                                        ..
# FIRST LEGO League Challenge 2010 - Body Forward v46     1
# FIRST LEGO League Challenge 2011 - Food Factor          1
# FIRST LEGO League Challenge 2012 - Senior Solutions     1
# FIRST LEGO League Challenge 2013 - Nature's Fury        1
# {Yellow Cab}                                            1
# Length: 10370, dtype: int64

# %%
lego_tidy3 = lego_tidy3.reset_index()
lego_tidy3[lego_tidy3['name']=='Basic Building Set'].head(3)
# Out:
# lego_info                name set_num  num_parts  theme_id
# 1769       Basic Building Set   010-3         77       366
# 1770       Basic Building Set   011-1        145       366
# 1771       Basic Building Set   022-1        110       366

# %%
bbset = lego.pivot_table(index='name',
           columns='lego_info',
           values='value').reset_index()
bbset
bbset[bbset['name']=="Basic Building Set"]
# Out:
# lego_info                name   num_parts    theme_id
# 1663       Basic Building Set  216.672727  454.363636

# %%
lego_tidy3[lego_tidy3['name']=='Basic Building Set'].describe()
# Out:
# lego_info   num_parts    theme_id
# count       55.000000   55.000000
# mean       216.672727  454.363636
# std        181.916959   34.062776
# min         22.000000  366.000000
# 25%         64.000000  467.000000
# 50%        176.000000  467.000000
# 75%        322.500000  467.000000
# max        721.000000  470.000000

# %% [markdown]
# ## Merging Data Frames

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'id' : [1,2,1,2],
                   'Max Speed': [390., 370., 24., 26.]})

df_food = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                                   'Parrot', 'Parrot'],
                        'id' : [1,2,1,2],
                        'Food': ['Dry', 'Meat', 'Seeds', 'Fruits']})

# %%
df.head()
# Out:
#    Animal  id  Max Speed
# 0  Falcon   1      390.0
# 1  Falcon   2      370.0
# 2  Parrot   1       24.0
# 3  Parrot   2       26.0

# %%
df_food
# Out:
#    Animal  id    Food
# 0  Falcon   1     Dry
# 1  Falcon   2    Meat
# 2  Parrot   1   Seeds
# 3  Parrot   2  Fruits

# %%
df_food.merge(df, on = 'Animal')
# Out:
#    Animal  id_x    Food  id_y  Max Speed
# 0  Falcon     1     Dry     1      390.0
# 1  Falcon     1     Dry     2      370.0
# 2  Falcon     2    Meat     1      390.0
# 3  Falcon     2    Meat     2      370.0
# 4  Parrot     1   Seeds     1       24.0
# 5  Parrot     1   Seeds     2       26.0
# 6  Parrot     2  Fruits     1       24.0
# 7  Parrot     2  Fruits     2       26.0

# %%
df.merge(df_food, on = ['Animal', 'id'])
# Out:
#    Animal  id  Max Speed    Food
# 0  Falcon   1      390.0     Dry
# 1  Falcon   2      370.0    Meat
# 2  Parrot   1       24.0   Seeds
# 3  Parrot   2       26.0  Fruits

# %%
df = pd.DataFrame({'an': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Id' : [1,2,1,2],
                   'Max Speed': [380., 370., 24., 26.]})
df_food = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                                   'Parrot', 'Parrot'],
                        'id' : [1,2,1,2],
                        'Food': ['Dry', 'Meat', 'Seeds', 'Fruits']})

# %%
df
# Out:
#        an  Id  Max Speed
# 0  Falcon   1      380.0
# 1  Falcon   2      370.0
# 2  Parrot   1       24.0
# 3  Parrot   2       26.0

# %%
df_food
# Out:
#    Animal  id    Food
# 0  Falcon   1     Dry
# 1  Falcon   2    Meat
# 2  Parrot   1   Seeds
# 3  Parrot   2  Fruits

# %%
df_animal = pd.DataFrame({'an': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Id' : [1,2,1,2],
                   'Max Speed': [380., 370., 24., 26.]})

# %%
df
# Out:
#    Animal  id  Max Speed
# 0  Falcon   1      390.0
# 1  Falcon   2      370.0
# 2  Parrot   1       24.0
# 3  Parrot   2       26.0

# %%
df_food
# Out:
#    Animal  id    Food
# 0  Falcon   1     Dry
# 1  Falcon   2    Meat
# 2  Parrot   1   Seeds
# 3  Parrot   2  Fruits

# %%
import pandas as pd
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'id' : [1,2,1, 1 ,2],
                   'Max Speed': [390., 350, 370., 24., 26.]})

df_food = pd.DataFrame({'Animal': ['Falcon', 'Falcon','Parrot', 'Parrot'
                                   ],
                        'id' : [1,2,1,2],
                        'Food': ['Dry', 'Meat', 'Seeds', 'Fruits']})

# %%
df
# Out:
#    Animal  id  Max Speed
# 0  Falcon   1      390.0
# 1  Falcon   2      350.0
# 2  Falcon   1      370.0
# 3  Parrot   1       24.0
# 4  Parrot   2       26.0

# %%
df_food
# Out:
#    Animal  id    Food
# 0  Falcon   1     Dry
# 1  Falcon   2    Meat
# 2  Parrot   1   Seeds
# 3  Parrot   2  Fruits

# %%
df.merge(df_food, on = ['Animal', 'id'])
# Out:
#    Animal  id  Max Speed    Food
# 0  Falcon   1      390.0     Dry
# 1  Falcon   1      370.0     Dry
# 2  Falcon   2      350.0    Meat
# 3  Parrot   1       24.0   Seeds
# 4  Parrot   2       26.0  Fruits

# %%
pd.concat([df, df_food])
# Out:
#    Animal  id  Max Speed    Food
# 0  Falcon   1      390.0     NaN
# 1  Falcon   2      350.0     NaN
# 2  Falcon   1      370.0     NaN
# 3  Parrot   1       24.0     NaN
# 4  Parrot   2       26.0     NaN
# 0  Falcon   1        NaN     Dry
# 1  Falcon   2        NaN    Meat
# 2  Parrot   1        NaN   Seeds
# 3  Parrot   2        NaN  Fruits

# %%
pd.concat([df, df_food], axis = 1)
# Out:
#    Animal  id  Max Speed  Animal   id    Food
# 0  Falcon   1      390.0  Falcon  1.0     Dry
# 1  Falcon   2      350.0  Falcon  2.0    Meat
# 2  Falcon   1      370.0  Parrot  1.0   Seeds
# 3  Parrot   1       24.0  Parrot  2.0  Fruits
# 4  Parrot   2       26.0     NaN  NaN     NaN

# %%
df_food
# Out:
#    Animal  id    Food
# 0  Falcon   1     Dry
# 1  Falcon   2    Meat
# 2  Parrot   1   Seeds
# 3  Parrot   2  Fruits

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon', 'Parrot', 'Parrot'],
                   'Id' :    [1,2,1,2],
                   'Max Speed': [380., 370., 24., 26.]})
df2 = pd.DataFrame({'Animal': ['Tiger', 'Tiger', 'Parrot', 'Rooster'],
                        'Id' : [1,2,1,2],
                        'Max Speed': [500., 470., 24., 46.]})

# %%
df
# Out:
#    Animal  Id  Max Speed
# 0  Falcon   1      380.0
# 1  Falcon   2      370.0
# 2  Parrot   1       24.0
# 3  Parrot   2       26.0

# %%
df2
# Out:
#     Animal  Id  Max Speed
# 0    Tiger   1      500.0
# 1    Tiger   2      470.0
# 2   Parrot   1       24.0
# 3  Rooster   2       46.0

# %% [markdown]
# ## Difference between Outer Merge and Concat

# %%
pd.concat([df, df2])
# Out:
#     Animal  Id  Max Speed
# 0   Falcon   1      380.0
# 1   Falcon   2      370.0
# 2   Parrot   1       24.0
# 3   Parrot   2       26.0
# 0    Tiger   1      500.0
# 1    Tiger   2      470.0
# 2   Parrot   1       24.0
# 3  Rooster   2       46.0

# %%
df.merge(df2, how="outer")
# Out:
#     Animal  Id  Max Speed
# 0   Falcon   1      380.0
# 1   Falcon   2      370.0
# 2   Parrot   1       24.0
# 3   Parrot   2       26.0
# 4    Tiger   1      500.0
# 5    Tiger   2      470.0
# 6  Rooster   2       46.0
