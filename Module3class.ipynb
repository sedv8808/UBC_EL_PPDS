# %% [markdown]
# # UBC
# ## Programming in Python for DS
# ### Week 3
# Instructor: Socorro Dominguez-Vidana

# %% [markdown]
# - [] Explain what **tidy data** is.
# - [] Use `.melt()` and `.pivot()`
# - [] Learn how to reset a data frame's index.
# - [] Combine data frames using `.merge()` and `.concat()`

# %% [markdown]
# ## Tidy Data

# %% [markdown]
# - The concept stems from a [paper](https://vita.had.co.nz/papers/tidy-data.pdf) written by Hadley Wickham in 2014.
# - We tidy our data to create a standard across multiple analysis tools.

# %% [markdown]
# Rules for Tidy Data:
#
# * each row is a single observation,
# * each column is a single variable, and
# * each value is a single cell (i.e., its entry in the data frame is not shared with another value).
#
# **Note:** Tidy data will also be defined in the context of the problem that you are solving.

# %% [markdown]
# ![](https://datasciencebook.ca/_main_files/figure-html/02-tidy-image-1.png)

# %% [markdown]
# Or:
#
# ![](https://datasciencebook.ca/_main_files/figure-html/02-obs-1.png)

# %% [markdown]
# ## What to do when data is not tidy...

# %% [markdown]
# Data sometimes comes in tables that are easy to read/make sense for humans.
#
# - However, they are not necessarily in the best format for computations to happen.
#
# Most common scenarios:
# - We need to convert from Wide to Long tables
# - We need to convert from Long to Wide tables
#
# ## Wide to Long

# %% [markdown]
# ## Goal

# %% [markdown]
# ![](https://datasciencebook.ca/img/wrangling/pivot_functions.001.png)

# %% [markdown]
# A common task:
# - Get data into a tidy format by combining values that are stored in separate columns, but are really part of the same variable, into one.
# - Data is often stored this way because this format is sometimes more intuitive for human readability.

# %% [markdown]
# ## From Long to Wide

# %% [markdown]
# ![](https://datasciencebook.ca/img/wrangling/pivot_functions.003.png)

# %% [markdown]
# - Sometimes we have observations spread across multiple rows rather than in a single row.
# - In the previous figure, the table on the left is in an untidy, long format because the count column contains three variables (*population*, *commuter count*, and *year the city was incorporated*) and information about each observation (here, *population*, *commuter*, and *incorporated* values for a region) is split across three rows.
# - **Remember:** one of the criteria for tidy data is that each observation must be in a single row.

# %% [markdown]
# ### How to Manipulate Long and Wide Tables In Python

# %% [markdown]
# ### Melt
#
# > wide to long format
#
# [Documentation](https://pandas.pydata.org/docs/reference/api/pandas.melt.html)
#
# ![](https://pandas.pydata.org/docs/_images/reshaping_melt.png)

# %%
import pandas as pd

cereal = pd.read_csv('https://raw.githubusercontent.com/UBC-MDS/programming-in-python-for-data-science/master/data/cereal.csv')
cereal = cereal.drop(labels=['type', 'shelf', 'weight', 'cups', 'rating'], axis=1)
cereal.head()
# Out:
#                         name mfr  calories  protein  fat  sodium  fiber
# 0                  100% Bran   N        70        4    1     130   10.0  \
# 1          100% Natural Bran   Q       120        3    5      15    2.0
# 2                   All-Bran   K        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K        50        4    0     140   14.0
# 4             Almond Delight   R       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins
# 0    5.0       6     280        25
# 1    8.0       8     135         0
# 2    7.0       5     320        25
# 3    8.0       0     330        25
# 4   14.0       8       1        25

# %%
cereal[cereal['name'] == '100% Bran']
# Out:
#         name mfr  calories  protein  fat  sodium  fiber  carbo  sugars
# 0  100% Bran   N        70        4    1     130   10.0    5.0       6  \
#
#    potass  vitamins
# 0     280        25

# %%
cereal_long = cereal.melt(id_vars=['name', 'mfr'])
cereal_long
cereal_long[cereal_long['name'] == '100% Bran']
# Out:
#           name mfr  variable  value
# 0    100% Bran   N  calories   70.0
# 77   100% Bran   N   protein    4.0
# 154  100% Bran   N       fat    1.0
# 231  100% Bran   N    sodium  130.0
# 308  100% Bran   N     fiber   10.0
# 385  100% Bran   N     carbo    5.0
# 462  100% Bran   N    sugars    6.0
# 539  100% Bran   N    potass  280.0
# 616  100% Bran   N  vitamins   25.0

# %% [markdown]
# ### Pivot
#
# > long to wide
#
# [Documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pivot.html)
#
#
# ![](https://pandas.pydata.org/docs/_images/reshaping_pivot.png)

# %%
lego = pd.read_csv('https://raw.githubusercontent.com/UBC-MDS/programming-in-python-for-data-science/master/data/lego_untidy.csv')
lego.head()
# Out:
#   set_num                          name  year  lego_info  value
# 0    00-1               Weetabix Castle  1970   theme_id    414
# 1    00-1               Weetabix Castle  1970  num_parts    471
# 2    00-2  Weetabix Promotional House 1  1976  num_parts    147
# 3    00-2  Weetabix Promotional House 1  1976   theme_id    413
# 4    00-3  Weetabix Promotional House 2  1976  num_parts    149

# %%
lego_tidy = lego.pivot(index='set_num',
                       columns='lego_info',
                       values='value')
lego_tidy
# Out:
# lego_info     num_parts  theme_id
# set_num
# 00-1                471       414
# 00-2                147       413
# 00-3                149       413
# 00-4                126       413
# 00-6                  3        67
# ...                 ...       ...
# tominifigs-1          2        50
# trucapam-1           71       598
# tsuper-1              3        12
# vwkit-1              22       366
# wwgp1-1               3       476
#
# [11673 rows x 2 columns]

# %%
lego_tidy = lego.pivot(index=['set_num', 'name'],
                       columns='lego_info',
                       values='value')
lego_tidy.head()
# Out:
# lego_info                              num_parts  theme_id
# set_num name
# 00-1    Weetabix Castle                      471       414
# 00-2    Weetabix Promotional House 1         147       413
# 00-3    Weetabix Promotional House 2         149       413
# 00-4    Weetabix Promotional Windmill        126       413
# 00-6    Special Offer                          3        67

# %%
lego_tidy2 = lego_tidy.reset_index()
lego_tidy2
# Out:
# lego_info       set_num                                 name  num_parts
# 0                  00-1                      Weetabix Castle        471  \
# 1                  00-2         Weetabix Promotional House 1        147
# 2                  00-3         Weetabix Promotional House 2        149
# 3                  00-4        Weetabix Promotional Windmill        126
# 4                  00-6                        Special Offer          3
# ...                 ...                                  ...        ...
# 11668      tominifigs-1            Town Minifig Packs 2-Pack          2
# 11669        trucapam-1               Captain America Mosaic         71
# 11670          tsuper-1                    Technic Super Set          3
# 11671           vwkit-1                       Volkswagen Kit         22
# 11672           wwgp1-1  Wild West Limited Edition Gift Pack          3
#
# lego_info  theme_id
# 0               414
# 1               413
# 2               413
# 3               413
# 4                67
# ...             ...
# 11668            50
# 11669           598
# 11670            12
# 11671           366
# 11672           476
#
# [11673 rows x 4 columns]

# %%
# What if I want to use only the name?
lego.pivot(index='name',
           columns='lego_info',
           values='value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 # What if I want to use only the name?
# ----> 2 lego.pivot(index='name',
#       3            columns='lego_info',
#       4            values='value')
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/frame.py:8419, in DataFrame.pivot(self, columns, index, values)
#    8414 @Substitution("")
#    8415 @Appender(_shared_docs["pivot"])
#    8416 def pivot(self, *, columns, index=lib.NoDefault, values=lib.NoDefault) -> DataFrame:
#    8417     from pandas.core.reshape.pivot import pivot
# -> 8419     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/reshape/pivot.py:555, in pivot(data, columns, index, values)
#     551         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     552 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     553 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     554 # "Hashable"
# --> 555 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     556 result.index.names = [
#     557     name if name is not lib.NoDefault else None for name in result.index.names
#     558 ]
#     560 return result
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/series.py:4314, in Series.unstack(self, level, fill_value)
#    4271 """
#    4272 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4273
#    (...)
#    4310 b    2    4
#    4311 """
#    4312 from pandas.core.reshape.reshape import unstack
# -> 4314 return unstack(self, level, fill_value)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/reshape/reshape.py:488, in unstack(obj, level, fill_value)
#     486 if is_1d_only_ea_dtype(obj.dtype):
#     487     return _unstack_extension_series(obj, level, fill_value)
# --> 488 unstacker = _Unstacker(
#     489     obj.index, level=level, constructor=obj._constructor_expanddim
#     490 )
#     491 return unstacker.get_result(
#     492     obj._values, value_columns=None, fill_value=fill_value
#     493 )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/reshape/reshape.py:136, in _Unstacker.__init__(self, index, level, constructor)
#     128 if num_cells > np.iinfo(np.int32).max:
#     129     warnings.warn(
#     130         f"The following operation may generate {num_cells} cells "
#     131         f"in the resulting pandas object.",
#     132         PerformanceWarning,
#     133         stacklevel=find_stack_level(),
#     134     )
# --> 136 self._make_selectors()
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/reshape/reshape.py:188, in _Unstacker._make_selectors(self)
#     185 mask.put(selector, True)
#     187 if mask.sum() < len(self.index):
# --> 188     raise ValueError("Index contains duplicate entries, cannot reshape")
#     190 self.group_index = comp_index
#     191 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %% [markdown]
# ## What duplicates?
#
# ### How do I find them?

# %%
lego_tidy.reset_index().value_counts('name')#.head()
# Out:
# name
# Basic Building Set                                     55
# Universal Building Set                                 32
# Helicopter                                             23
# Basic Set                                              23
# Fire Station                                           14
#                                                        ..
# FIRST LEGO League Challenge 2010 - Body Forward v46     1
# FIRST LEGO League Challenge 2011 - Food Factor          1
# FIRST LEGO League Challenge 2012 - Senior Solutions     1
# FIRST LEGO League Challenge 2013 - Nature's Fury        1
# {Yellow Cab}                                            1
# Name: count, Length: 10370, dtype: int64

# %%
bbset = lego[lego['name'] == 'Basic Building Set']
bbset
# Out:
#                              set_num                name  year  lego_info
# typing.Literal[<no_default>]
# 30                             010-3  Basic Building Set  1968  num_parts  \
# 31                             010-3  Basic Building Set  1968   theme_id
# 32                             011-1  Basic Building Set  1968  num_parts
# 33                             011-1  Basic Building Set  1968   theme_id
# 34                             022-1  Basic Building Set  1968  num_parts
# ...                              ...                 ...   ...        ...
# 15727                          730-2  Basic Building Set  1985  num_parts
# 15842                          735-1  Basic Building Set  1990  num_parts
# 15843                          735-1  Basic Building Set  1990   theme_id
# 15846                          740-1  Basic Building Set  1985  num_parts
# 15847                          740-1  Basic Building Set  1985   theme_id
#
#                               value
# typing.Literal[<no_default>]
# 30                               77
# 31                              366
# 32                              145
# 33                              366
# 34                              110
# ...                             ...
# 15727                           432
# 15842                           538
# 15843                           467
# 15846                           530
# 15847                           467
#
# [110 rows x 5 columns]

# %%
bbset.pivot(index=['set_num', 'name'],
                       columns='lego_info',
                       values='value').head()
# Out:
# lego_info                   num_parts  theme_id
# set_num name
# 010-3   Basic Building Set         77       366
# 011-1   Basic Building Set        145       366
# 022-1   Basic Building Set        110       366
# 033-2   Basic Building Set        177       366
# 044-1   Basic Building Set        225       366

# %% [markdown]
# What if I do not care about the `set_num`, just about the `name`?

# %% [markdown]
# ### Alternative: Use `pivot_table`

# %%
bbset.head()
# Out:
#                              set_num                name  year  lego_info
# typing.Literal[<no_default>]
# 30                             010-3  Basic Building Set  1968  num_parts  \
# 31                             010-3  Basic Building Set  1968   theme_id
# 32                             011-1  Basic Building Set  1968  num_parts
# 33                             011-1  Basic Building Set  1968   theme_id
# 34                             022-1  Basic Building Set  1968  num_parts
#
#                               value
# typing.Literal[<no_default>]
# 30                               77
# 31                              366
# 32                              145
# 33                              366
# 34                              110

# %%
bbset2 = lego.pivot_table(index='name',
           columns='lego_info',
           values='value', aggfunc='mean').reset_index()
bbset2
# Out:
# lego_info                              name  num_parts  theme_id
# 0                 1 stud Blue Storage Brick        0.0     501.0
# 1           Scenery and Dagger Trap polybag       25.0     435.0
# 2                                   Spectre        7.0     552.0
# 3                  White Spaceman Key Chain        0.0     503.0
# 4                 'Where Are My Pants?' Guy        6.0     549.0
# ...                                     ...        ...       ...
# 10365               {Red Race Car Number 3}       39.0      82.0
# 10366              {Roadplates and Scenery}       85.0     533.0
# 10367                    {Rock Saw Vehicle}       22.0     442.0
# 10368                       {Town Vehicles}      158.0     533.0
# 10369                          {Yellow Cab}       44.0      22.0
#
# [10370 rows x 3 columns]

# %%
bbset2[bbset2['name']=="Basic Building Set"]
# Out:
# lego_info                name   num_parts    theme_id
# 1663       Basic Building Set  216.672727  454.363636

# %%
bbset
# Out:
#                              set_num                name  year  lego_info
# typing.Literal[<no_default>]
# 30                             010-3  Basic Building Set  1968  num_parts  \
# 31                             010-3  Basic Building Set  1968   theme_id
# 32                             011-1  Basic Building Set  1968  num_parts
# 33                             011-1  Basic Building Set  1968   theme_id
# 34                             022-1  Basic Building Set  1968  num_parts
# ...                              ...                 ...   ...        ...
# 15727                          730-2  Basic Building Set  1985  num_parts
# 15842                          735-1  Basic Building Set  1990  num_parts
# 15843                          735-1  Basic Building Set  1990   theme_id
# 15846                          740-1  Basic Building Set  1985  num_parts
# 15847                          740-1  Basic Building Set  1985   theme_id
#
#                               value
# typing.Literal[<no_default>]
# 30                               77
# 31                              366
# 32                              145
# 33                              366
# 34                              110
# ...                             ...
# 15727                           432
# 15842                           538
# 15843                           467
# 15846                           530
# 15847                           467
#
# [110 rows x 5 columns]

# %%
bbset.shape
# Out:
# (110, 5)

# %%
bbset.pivot(index=['set_num', 'name'],
                       columns='lego_info',
                       values='value').reset_index()['num_parts'].mean()
# Out:
# 216.6727272727273

# %%
bbset.pivot(index=['set_num', 'name'],
                       columns='lego_info',
                       values='value').reset_index()['theme_id'].mean()
# Out:
# 454.3636363636364

# %% [markdown]
# ## Merging Data Frames

# %%
df = pd.DataFrame({'animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'id' : [1, 2, 1, 2],
                   'speed': [390., 370., 24., 26.]})

df_food = pd.DataFrame({'animal': ['Falcon', 'Falcon',
                                   'Parrot', 'Parrot'],
                        'id' : [1, 2, 1, 2],
                        'food': ['kibble', 'meat', 'seeds', 'fruits']})

# %%
df
# Out:
#    animal  id  speed
# 0  Falcon   1  390.0
# 1  Falcon   2  370.0
# 2  Parrot   1   24.0
# 3  Parrot   2   26.0

# %%
df_food
# Out:
#    animal  id    food
# 0  Falcon   1  kibble
# 1  Falcon   2    meat
# 2  Parrot   1   seeds
# 3  Parrot   2  fruits

# %%
df.merge(df_food, on = 'animal')
# Out:
#    animal  id_x  speed  id_y    food
# 0  Falcon     1  390.0     1  kibble
# 1  Falcon     1  390.0     2    meat
# 2  Falcon     2  370.0     1  kibble
# 3  Falcon     2  370.0     2    meat
# 4  Parrot     1   24.0     1   seeds
# 5  Parrot     1   24.0     2  fruits
# 6  Parrot     2   26.0     1   seeds
# 7  Parrot     2   26.0     2  fruits

# %%
df.merge(df_food, on = ['animal', 'id'])
# Out:
#    animal  id  speed    food
# 0  Falcon   1  390.0  kibble
# 1  Falcon   2  370.0    meat
# 2  Parrot   1   24.0   seeds
# 3  Parrot   2   26.0  fruits

# %%
df.merge(df_food, on = ['animal', 'id'], how='right')
# Out:
#    animal  id  speed    food
# 0  Falcon   1  390.0  kibble
# 1  Falcon   2  370.0    meat
# 2  Parrot   1   24.0   seeds
# 3  Parrot   2   26.0  fruits

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'ID' : [1, 2, 1, 2],
                   'Speed': [380, 370, 24, 26]})
df_food = pd.DataFrame({'animal': ['Falcon', 'Falcon',
                                   'Parrot', 'Parrot',
                                   'Tiger'],
                        'id' : [1, 2, 1, 2, 1],
                        'food': ['kibble', 'meat', 'seeds', 'fruits', 'meat']})
df_food2 = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                                   'Parrot', 'Parrot',
                                   'Tiger'],
                        'ID' : [1, 2, 1, 2, 1],
                        'Food': ['kibble', 'meat', 'seeds', 'fruits', 'meat']})

# %%
df
# Out:
#    Animal  ID  Speed
# 0  Falcon   1    380
# 1  Falcon   2    370
# 2  Parrot   1     24
# 3  Parrot   2     26

# %%
df_food
# Out:
#    animal  id    food
# 0  Falcon   1  kibble
# 1  Falcon   2    meat
# 2  Parrot   1   seeds
# 3  Parrot   2  fruits
# 4   Tiger   1    meat

# %%
df2 = df.merge(df_food, left_on = ['Animal', 'ID'], right_on = ['animal', 'id'], how='outer', indicator=True)
df2
# Out:
#    Animal   ID  Speed  animal  id    food      _merge
# 0  Falcon  1.0  380.0  Falcon   1  kibble        both
# 1  Falcon  2.0  370.0  Falcon   2    meat        both
# 2  Parrot  1.0   24.0  Parrot   1   seeds        both
# 3  Parrot  2.0   26.0  Parrot   2  fruits        both
# 4     NaN  NaN    NaN   Tiger   1    meat  right_only

# %%
df2[df2['_merge']=='right_only']
# Out:
#   Animal  ID  Speed animal  id  food      _merge
# 4    NaN NaN    NaN  Tiger   1  meat  right_only

# %% [markdown]
# ## Difference with Concat

# %%
df
# Out:
#    Animal  ID  Speed
# 0  Falcon   1    380
# 1  Falcon   2    370
# 2  Parrot   1     24
# 3  Parrot   2     26

# %%
df_food2
# Out:
#    Animal  ID    Food
# 0  Falcon   1  kibble
# 1  Falcon   2    meat
# 2  Parrot   1   seeds
# 3  Parrot   2  fruits
# 4   Tiger   1    meat

# %%
pd.concat([df, df_food2])
# Out:
#    Animal  ID  Speed    Food
# 0  Falcon   1  380.0     NaN
# 1  Falcon   2  370.0     NaN
# 2  Parrot   1   24.0     NaN
# 3  Parrot   2   26.0     NaN
# 0  Falcon   1    NaN  kibble
# 1  Falcon   2    NaN    meat
# 2  Parrot   1    NaN   seeds
# 3  Parrot   2    NaN  fruits
# 4   Tiger   1    NaN    meat

# %%
df_food
# Out:
#    animal  id    food
# 0  Falcon   1  kibble
# 1  Falcon   2    meat
# 2  Parrot   1   seeds
# 3  Parrot   2  fruits
# 4   Tiger   1    meat

# %%
df.columns = df_food.columns

# %%
pd.concat([df, df_food])
# Out:
#    animal  id    food
# 0  Falcon   1     380
# 1  Falcon   2     370
# 2  Parrot   1      24
# 3  Parrot   2      26
# 0  Falcon   1  kibble
# 1  Falcon   2    meat
# 2  Parrot   1   seeds
# 3  Parrot   2  fruits
# 4   Tiger   1    meat

# %% [markdown]
# ### Concatenating sideways ("merging" by position?)

# %%
df3 = pd.concat([df_food, df], axis = 1)
df3
# Out:
#    animal  id    food  animal   id   food
# 0  Falcon   1  kibble  Falcon  1.0  380.0
# 1  Falcon   2    meat  Falcon  2.0  370.0
# 2  Parrot   1   seeds  Parrot  1.0   24.0
# 3  Parrot   2  fruits  Parrot  2.0   26.0
# 4   Tiger   1    meat     NaN  NaN    NaN

# %%
df4 = df3[['animal', 'id']]
df4
# Out:
#    animal  animal  id   id
# 0  Falcon  Falcon   1  1.0
# 1  Falcon  Falcon   2  2.0
# 2  Parrot  Parrot   1  1.0
# 3  Parrot  Parrot   2  2.0
# 4   Tiger     NaN   1  NaN

# %%
df4[df4['animal'] == 'Parrot']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df4[df4['animal'] == 'Parrot']
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/frame.py:3747, in DataFrame.__getitem__(self, key)
#    3745 # Do we have a (boolean) DataFrame?
#    3746 if isinstance(key, DataFrame):
# -> 3747     return self.where(key)
#    3749 # Do we have a (boolean) 1d indexer?
#    3750 if com.is_bool_indexer(key):
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/frame.py:11527, in DataFrame.where(self, cond, other, inplace, axis, level)
#   11518 def where(
#   11519     self,
#   11520     cond,
#    (...)
#   11525     level: Level = None,
#   11526 ) -> DataFrame | None:
# > 11527     return super().where(
#   11528         cond,
#   11529         other,
#   11530         inplace=inplace,
#   11531         axis=axis,
#   11532         level=level,
#   11533     )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py:9940, in NDFrame.where(self, cond, other, inplace, axis, level)
#    9802 """
#    9803 Replace values where the condition is {cond_rev}.
#    9804
#    (...)
#    9937 4  True  True
#    9938 """
#    9939 other = common.apply_if_callable(other, self)
# -> 9940 return self._where(cond, other, inplace, axis, level)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py:9667, in NDFrame._where(self, cond, other, inplace, axis, level)
#    9664     cond = cond.astype(bool)
#    9666 cond = -cond if inplace else cond
# -> 9667 cond = cond.reindex(self._info_axis, axis=self._info_axis_number, copy=False)
#    9669 # try to align with other
#    9670 if isinstance(other, NDFrame):
#    9671     # align with me
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/frame.py:5063, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5044 @doc(
#    5045     NDFrame.reindex,
#    5046     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5061     tolerance=None,
#    5062 ) -> DataFrame:
# -> 5063     return super().reindex(
#    5064         labels=labels,
#    5065         index=index,
#    5066         columns=columns,
#    5067         axis=axis,
#    5068         method=method,
#    5069         copy=copy,
#    5070         level=level,
#    5071         fill_value=fill_value,
#    5072         limit=limit,
#    5073         tolerance=tolerance,
#    5074     )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py:5360, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5357     return self._reindex_multi(axes, copy, fill_value)
#    5359 # perform the reindex on the axes
# -> 5360 return self._reindex_axes(
#    5361     axes, level, limit, tolerance, method, fill_value, copy
#    5362 ).__finalize__(self, method="reindex")
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/frame.py:4898, in DataFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4896 columns = axes["columns"]
#    4897 if columns is not None:
# -> 4898     frame = frame._reindex_columns(
#    4899         columns, method, copy, level, fill_value, limit, tolerance
#    4900     )
#    4902 index = axes["index"]
#    4903 if index is not None:
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/frame.py:4940, in DataFrame._reindex_columns(self, new_columns, method, copy, level, fill_value, limit, tolerance)
#    4930 def _reindex_columns(
#    4931     self,
#    4932     new_columns,
#    (...)
#    4938     tolerance=None,
#    4939 ):
# -> 4940     new_columns, indexer = self.columns.reindex(
#    4941         new_columns, method=method, level=level, limit=limit, tolerance=tolerance
#    4942     )
#    4943     return self._reindex_with_indexers(
#    4944         {1: [new_columns, indexer]},
#    4945         copy=copy,
#    4946         fill_value=fill_value,
#    4947         allow_dups=False,
#    4948     )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:4274, in Index.reindex(self, target, method, level, limit, tolerance)
#    4271     raise ValueError("cannot handle a non-unique multi-index!")
#    4272 elif not self.is_unique:
#    4273     # GH#42568
# -> 4274     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4275 else:
#    4276     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels
