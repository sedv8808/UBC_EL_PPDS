# %% [markdown]
# # UBC - KCDS
#
# ## PPDS
#
# ### Week 3
# Instructor: Socorro Dominguez-Vidana

# %% [markdown]
# - [] Explain what **tidy data** is.
# - [] Use `.melt()` and `.pivot()` / `.pivot_table()`
# - [] Learn how to reset a data frame's index.
# - [] Combine data frames using `.merge()` and `.concat()`

# %% [markdown]
# ## Tidy Data

# %% [markdown]
# - The concept stems from a [paper](https://vita.had.co.nz/papers/tidy-data.pdf) written by Hadley Wickham in 2014.
# - We tidy our data to create a standard across multiple analysis tools.

# %% [markdown]
# Rules for Tidy Data:
#
# * each row is a single observation,
# * each column is a single variable, and
# * each value is a single cell (i.e., its entry in the data frame is not shared with another value).

# %% [markdown]
# ![](https://datasciencebook.ca/_main_files/figure-html/02-obs-1.png)

# %% [markdown]
# ## What to do when data is not tidy...

# %% [markdown]
# Data sometimes comes in tables that are easy to read/make sense for humans.
#
# - However, they are not necessarily in the best format for computations to happen.
#
# Most common scenarios:
# - We need to convert from Wide to Long tables
# - We need to convert from Long to Wide tables
#
# ## Wide to Long

# %% [markdown]
# ## Goal

# %% [markdown]
# ![](https://datasciencebook.ca/img/wrangling/pivot_functions.001.png)

# %% [markdown]
# A common task:
# - Get data into a tidy format by combining values that are stored in separate columns, but are really part of the same variable, into one.
# - Data is often stored this way because this format is sometimes more intuitive for human readability.
#
# - The format above on the left would be difficult to use when performing data visualization or statistical analysis. To find the latest year, we would need to work with the column names; it would be more challenging if you wanted to find the value for the population for a given region for the latest year. In the right format, this becomes very straight forward.
#
# - We also do not know what the values on the left really represent: land? population? We solve it with the format on the right.

# %% [markdown]
# ## From Long to Wide

# %% [markdown]
# ![](https://datasciencebook.ca/img/wrangling/pivot_functions.002.png)

# %% [markdown]
# - In the previous figure, the table on the left is in an untidy, long format because:
# - The **values** of the variable **region** are stored as column names and not easily accessible.
# - The **type values** are spread across multiple columns, which will prevent us from doing any desired visualization or statistical tasks.
# - **Remember:** one of the criteria for tidy data is that each observation must be in a single row.
# - We can still get the information out from the "wrong" format. However, it would be more challenging.

# %% [markdown]
# ### How to Manipulate Long and Wide Tables In Python

# %% [markdown]
# ### Melt
#
# > wide to long format
#
# [Documentation](https://pandas.pydata.org/docs/reference/api/pandas.melt.html)
#
# ![](https://pandas.pydata.org/docs/_images/reshaping_melt.png)

# %%
import pandas as pd

cereal = pd.read_csv('https://raw.githubusercontent.com/UBC-MDS/programming-in-python-for-data-science/master/data/cereal.csv')
cereal = cereal.drop(labels=['type', 'shelf', 'weight', 'cups', 'rating'], axis=1)
cereal.head()
# Out:
#                         name mfr  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N        70        4    1     130   10.0
# 1          100% Natural Bran   Q       120        3    5      15    2.0
# 2                   All-Bran   K        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K        50        4    0     140   14.0
# 4             Almond Delight   R       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins
# 0    5.0       6     280        25
# 1    8.0       8     135         0
# 2    7.0       5     320        25
# 3    8.0       0     330        25
# 4   14.0       8       1        25

# %%
cereal['name'].value_counts()
# Out:
# name
# 100% Bran                    1
# 100% Natural Bran            1
# All-Bran                     1
# All-Bran with Extra Fiber    1
# Almond Delight               1
#                             ..
# Triples                      1
# Trix                         1
# Wheat Chex                   1
# Wheaties                     1
# Wheaties Honey Gold          1
# Name: count, Length: 77, dtype: int64

# %%
cereal_long = cereal.melt(id_vars=['name', 'mfr'])
cereal_long
# Out:
#                           name mfr  variable  value
# 0                    100% Bran   N  calories   70.0
# 1            100% Natural Bran   Q  calories  120.0
# 2                     All-Bran   K  calories   70.0
# 3    All-Bran with Extra Fiber   K  calories   50.0
# 4               Almond Delight   R  calories  110.0
# ..                         ...  ..       ...    ...
# 688                    Triples   G  vitamins   25.0
# 689                       Trix   G  vitamins   25.0
# 690                 Wheat Chex   R  vitamins   25.0
# 691                   Wheaties   G  vitamins   25.0
# 692        Wheaties Honey Gold   G  vitamins   25.0
#
# [693 rows x 4 columns]

# %%
cereal_long[cereal_long['name'] == '100% Bran']
# Out:
#           name mfr  variable  value
# 0    100% Bran   N  calories   70.0
# 77   100% Bran   N   protein    4.0
# 154  100% Bran   N       fat    1.0
# 231  100% Bran   N    sodium  130.0
# 308  100% Bran   N     fiber   10.0
# 385  100% Bran   N     carbo    5.0
# 462  100% Bran   N    sugars    6.0
# 539  100% Bran   N    potass  280.0
# 616  100% Bran   N  vitamins   25.0

# %% [markdown]
# ### Pivot
#
# > long to wide
#
# [Documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pivot.html)
#
#
# ![](https://pandas.pydata.org/docs/_images/reshaping_pivot.png)

# %%
lego = pd.read_csv('https://raw.githubusercontent.com/UBC-MDS/programming-in-python-for-data-science/master/data/lego_untidy.csv')
lego.head()
# Out:
#   set_num                          name  year  lego_info  value
# 0    00-1               Weetabix Castle  1970   theme_id    414
# 1    00-1               Weetabix Castle  1970  num_parts    471
# 2    00-2  Weetabix Promotional House 1  1976  num_parts    147
# 3    00-2  Weetabix Promotional House 1  1976   theme_id    413
# 4    00-3  Weetabix Promotional House 2  1976  num_parts    149

# %%
lego_tidy = lego.pivot(index='set_num',
                       columns='lego_info',
                       values='value')
lego_tidy.reset_index()
# Out:
# lego_info       set_num  num_parts  theme_id
# 0                  00-1        471       414
# 1                  00-2        147       413
# 2                  00-3        149       413
# 3                  00-4        126       413
# 4                  00-6          3        67
# ...                 ...        ...       ...
# 11668      tominifigs-1          2        50
# 11669        trucapam-1         71       598
# 11670          tsuper-1          3        12
# 11671           vwkit-1         22       366
# 11672           wwgp1-1          3       476
#
# [11673 rows x 3 columns]

# %%
lego_tidy = lego.pivot(index=['set_num', 'name'],
                       columns='lego_info',
                       values='value')
lego_tidy.head().reset_index()
# Out:
# lego_info set_num                           name  num_parts  theme_id
# 0            00-1                Weetabix Castle        471       414
# 1            00-2   Weetabix Promotional House 1        147       413
# 2            00-3   Weetabix Promotional House 2        149       413
# 3            00-4  Weetabix Promotional Windmill        126       413
# 4            00-6                  Special Offer          3        67

# %%
lego_tidy2 = lego_tidy.reset_index()
lego_tidy2
# Out:
# lego_info       set_num                                 name  num_parts  \
# 0                  00-1                      Weetabix Castle        471
# 1                  00-2         Weetabix Promotional House 1        147
# 2                  00-3         Weetabix Promotional House 2        149
# 3                  00-4        Weetabix Promotional Windmill        126
# 4                  00-6                        Special Offer          3
# ...                 ...                                  ...        ...
# 11668      tominifigs-1            Town Minifig Packs 2-Pack          2
# 11669        trucapam-1               Captain America Mosaic         71
# 11670          tsuper-1                    Technic Super Set          3
# 11671           vwkit-1                       Volkswagen Kit         22
# 11672           wwgp1-1  Wild West Limited Edition Gift Pack          3
#
# lego_info  theme_id
# 0               414
# 1               413
# 2               413
# 3               413
# 4                67
# ...             ...
# 11668            50
# 11669           598
# 11670            12
# 11671           366
# 11672           476
#
# [11673 rows x 4 columns]

# %%
# What if I want to use only the name?
lego.pivot(index='name',
           columns='lego_info',
           values='value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # What if I want to use only the name?
# ----> 2 lego.pivot(index='name',
#       3            columns='lego_info',
#       4            values='value')
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/frame.py:10970, in DataFrame.pivot(self, columns, index, values)
#   10963 @Substitution("")
#   10964 @Appender(_shared_docs["pivot"])
#   10965 def pivot(
#   10966     self, *, columns, index=lib.no_default, values=lib.no_default
#   10967 ) -> DataFrame:
#   10968     from pandas.core.reshape.pivot import pivot
# > 10970     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:910, in pivot(data, columns, index, values)
#     905         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     906 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     907 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     908 # "Hashable"
#     909 # unstack with a MultiIndex returns a DataFrame
# --> 910 result = cast("DataFrame", indexed.unstack(columns_listlike))  # type: ignore[arg-type]
#     911 result.index.names = [
#     912     name if name is not lib.no_default else None for name in result.index.names
#     913 ]
#     915 return result
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/series.py:4501, in Series.unstack(self, level, fill_value, sort)
#    4451 """
#    4452 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4453
#    (...)   4497 b    2    4
#    4498 """
#    4499 from pandas.core.reshape.reshape import unstack
# -> 4501 return unstack(self, level, fill_value, sort)
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:596, in unstack(obj, level, fill_value, sort)
#     594 if is_1d_only_ea_dtype(obj.dtype):
#     595     return _unstack_extension_series(obj, level, fill_value, sort=sort)
# --> 596 unstacker = _Unstacker(
#     597     obj.index, level=level, constructor=obj._constructor_expanddim, sort=sort
#     598 )
#     599 return unstacker.get_result(obj, value_columns=None, fill_value=fill_value)
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:176, in _Unstacker.__init__(self, index, level, constructor, sort)
#     168     if num_cells > np.iinfo(np.int32).max:
#     169         warnings.warn(
#     170             f"The following operation may generate {num_cells} cells "
#     171             f"in the resulting pandas object.",
#     172             PerformanceWarning,
#     173             stacklevel=find_stack_level(),
#     174         )
# --> 176 self._make_selectors()
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:232, in _Unstacker._make_selectors(self)
#     229 mask.put(selector, True)
#     231 if mask.sum() < len(self.index):
# --> 232     raise ValueError("Index contains duplicate entries, cannot reshape")
#     234 self.group_index = comp_index
#     235 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %% [markdown]
# ## What duplicates?
#
# ### How do I find them?

# %%
lego_tidy.reset_index().value_counts('name').head()
# Out:
# name
# Basic Building Set        55
# Universal Building Set    32
# Basic Set                 23
# Helicopter                23
# Fire Station              14
# Name: count, dtype: int64

# %%
bbset = lego[lego['name'] == 'Basic Building Set']
bbset
# Out:
#       set_num                name  year  lego_info  value
# 30      010-3  Basic Building Set  1968  num_parts     77
# 31      010-3  Basic Building Set  1968   theme_id    366
# 32      011-1  Basic Building Set  1968  num_parts    145
# 33      011-1  Basic Building Set  1968   theme_id    366
# 34      022-1  Basic Building Set  1968  num_parts    110
# ...       ...                 ...   ...        ...    ...
# 15727   730-2  Basic Building Set  1985  num_parts    432
# 15842   735-1  Basic Building Set  1990  num_parts    538
# 15843   735-1  Basic Building Set  1990   theme_id    467
# 15846   740-1  Basic Building Set  1985  num_parts    530
# 15847   740-1  Basic Building Set  1985   theme_id    467
#
# [110 rows x 5 columns]

# %%
# Show with lego too
bbset.pivot(index=['set_num','name'],
                       columns='lego_info',
                       values='value')
# Out:
# lego_info                    num_parts  theme_id
# set_num  name
# 010-3    Basic Building Set         77       366
# 011-1    Basic Building Set        145       366
# 022-1    Basic Building Set        110       366
# 033-2    Basic Building Set        177       366
# 044-1    Basic Building Set        225       366
# 055-2    Basic Building Set        256       366
# 066-1    Basic Building Set        407       366
# 1106-2   Basic Building Set        413       470
# 120438-1 Basic Building Set        176       469
# 1562-2   Basic Building Set         36       467
# 1676-1   Basic Building Set         22       467
# 1679-1   Basic Building Set         43       467
# 1922-2   Basic Building Set         60       469
# 1962-1   Basic Building Set        219       467
# 1964-1   Basic Building Set         27       467
# 1965-1   Basic Building Set         38       469
# 303-1    Basic Building Set         33       467
# 304-1    Basic Building Set         31       467
# 308-2    Basic Building Set         34       467
# 310-4    Basic Building Set         46       467
# 315-1    Basic Building Set         62       467
# 317-2    Basic Building Set         68       467
# 320-1    Basic Building Set         78       467
# 325-1    Basic Building Set        109       467
# 327-1    Basic Building Set        107       467
# 330-1    Basic Building Set        158       467
# 335-1    Basic Building Set        245       467
# 337-1    Basic Building Set        225       467
# 340-1    Basic Building Set        220       467
# 347-2    Basic Building Set        330       467
# 350-2    Basic Building Set        315       467
# 4122-1   Basic Building Set        201       470
# 503-1    Basic Building Set         39       467
# 504-1    Basic Building Set         41       467
# 507-1    Basic Building Set         60       467
# 508-1    Basic Building Set         66       467
# 510-1    Basic Building Set        102       467
# 515-1    Basic Building Set        115       467
# 517-1    Basic Building Set        123       467
# 520-16   Basic Building Set        173       467
# 525-1    Basic Building Set        185       467
# 527-1    Basic Building Set        196       467
# 530-1    Basic Building Set        273       467
# 535-1    Basic Building Set        349       467
# 537-1    Basic Building Set        271       467
# 540-1    Basic Building Set        619       467
# 547-1    Basic Building Set        624       467
# 550-1    Basic Building Set        578       467
# 557-1    Basic Building Set        721       467
# 715-1    Basic Building Set        410       467
# 720-1    Basic Building Set        339       467
# 725-1    Basic Building Set        440       467
# 730-2    Basic Building Set        432       467
# 735-1    Basic Building Set        538       467
# 740-1    Basic Building Set        530       467

# %% [markdown]
# What if I do not care about the `set_num`, just about the `name`?

# %% [markdown]
# ### Alternative: Use `pivot_table`

# %%
bbset.head()
# Out:
#    set_num                name  year  lego_info  value
# 30   010-3  Basic Building Set  1968  num_parts     77
# 31   010-3  Basic Building Set  1968   theme_id    366
# 32   011-1  Basic Building Set  1968  num_parts    145
# 33   011-1  Basic Building Set  1968   theme_id    366
# 34   022-1  Basic Building Set  1968  num_parts    110

# %%
bbset2 = lego.pivot_table(index='name',
           columns='lego_info',
           values='value') #, aggfunc='mean').reset_index()
bbset2 = bbset2.reset_index()
bbset2
# Out:
# lego_info                              name  num_parts  theme_id
# 0                 1 stud Blue Storage Brick        0.0     501.0
# 1           Scenery and Dagger Trap polybag       25.0     435.0
# 2                                   Spectre        7.0     552.0
# 3                  White Spaceman Key Chain        0.0     503.0
# 4                 'Where Are My Pants?' Guy        6.0     549.0
# ...                                     ...        ...       ...
# 10365               {Red Race Car Number 3}       39.0      82.0
# 10366              {Roadplates and Scenery}       85.0     533.0
# 10367                    {Rock Saw Vehicle}       22.0     442.0
# 10368                       {Town Vehicles}      158.0     533.0
# 10369                          {Yellow Cab}       44.0      22.0
#
# [10370 rows x 3 columns]

# %%
bbset2[bbset2['name']=="Basic Building Set"]
# Out:
# lego_info                name   num_parts    theme_id
# 1663       Basic Building Set  216.672727  454.363636

# %%
bbset
# Out:
#       set_num                name  year  lego_info  value
# 30      010-3  Basic Building Set  1968  num_parts     77
# 31      010-3  Basic Building Set  1968   theme_id    366
# 32      011-1  Basic Building Set  1968  num_parts    145
# 33      011-1  Basic Building Set  1968   theme_id    366
# 34      022-1  Basic Building Set  1968  num_parts    110
# ...       ...                 ...   ...        ...    ...
# 15727   730-2  Basic Building Set  1985  num_parts    432
# 15842   735-1  Basic Building Set  1990  num_parts    538
# 15843   735-1  Basic Building Set  1990   theme_id    467
# 15846   740-1  Basic Building Set  1985  num_parts    530
# 15847   740-1  Basic Building Set  1985   theme_id    467
#
# [110 rows x 5 columns]

# %%
bbset.shape
# Out:
# (110, 5)

# %%
bbset.pivot(index=['set_num', 'name'],
                       columns='lego_info',
                       values='value').reset_index()['num_parts'].mean()
# Out:
# np.float64(216.6727272727273)

# %%
bbset.pivot(index=['set_num', 'name'],
                       columns='lego_info',
                       values='value').reset_index()['theme_id'].mean()
# Out:
# np.float64(454.3636363636364)

# %% [markdown]
# ## Merging Data Frames

# %%
df = pd.DataFrame({'animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'id' : [1, 2, 1, 2],
                   'speed': [390., 370., 24., 26.]})

df_food = pd.DataFrame({'animal': ['Falcon', 'Falcon',
                                   'Parrot', 'Parrot'],
                        'id' : [1, 2, 1, 2],
                        'food': ['kibble', 'meat', 'seeds', 'fruits']})

# %%
df
# Out:
#    animal  id  speed
# 0  Falcon   1  390.0
# 1  Falcon   2  370.0
# 2  Parrot   1   24.0
# 3  Parrot   2   26.0

# %%
df_food
# Out:
#    animal  id    food
# 0  Falcon   1  kibble
# 1  Falcon   2    meat
# 2  Parrot   1   seeds
# 3  Parrot   2  fruits

# %%
df.merge(df_food, on = 'animal')
# Out:
#    animal  id_x  speed  id_y    food
# 0  Falcon     1  390.0     1  kibble
# 1  Falcon     1  390.0     2    meat
# 2  Falcon     2  370.0     1  kibble
# 3  Falcon     2  370.0     2    meat
# 4  Parrot     1   24.0     1   seeds
# 5  Parrot     1   24.0     2  fruits
# 6  Parrot     2   26.0     1   seeds
# 7  Parrot     2   26.0     2  fruits

# %%
df.merge(df_food, on = ['animal', 'id'])
# Out:
#    animal  id  speed    food
# 0  Falcon   1  390.0  kibble
# 1  Falcon   2  370.0    meat
# 2  Parrot   1   24.0   seeds
# 3  Parrot   2   26.0  fruits

# %%
df.merge(df_food, on = ['animal', 'id'], how='left')
# Out:
#    animal  id  speed    food
# 0  Falcon   1  390.0  kibble
# 1  Falcon   2  370.0    meat
# 2  Parrot   1   24.0   seeds
# 3  Parrot   2   26.0  fruits

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'ID' : [1, 2, 1, 2],
                   'Speed': [380, 370, 24, 26]})
df_food = pd.DataFrame({'animal': ['Falcon', 'Falcon',
                                   'Parrot', 'Parrot',
                                   'Tiger'],
                        'id' : [1, 2, 1, 2, 1],
                        'food': ['kibble', 'meat', 'seeds', 'fruits', 'meat']})

# %%
df
# Out:
#    Animal  ID  Speed
# 0  Falcon   1    380
# 1  Falcon   2    370
# 2  Parrot   1     24
# 3  Parrot   2     26

# %%
df_food
# Out:
#    animal  id    food
# 0  Falcon   1  kibble
# 1  Falcon   2    meat
# 2  Parrot   1   seeds
# 3  Parrot   2  fruits
# 4   Tiger   1    meat

# %%
df.merge(df_food, left_on = ['Animal', 'ID'], right_on = ['animal', 'id'], how='outer', indicator=True)
# Out:
#    Animal   ID  Speed  animal  id    food      _merge
# 0  Falcon  1.0  380.0  Falcon   1  kibble        both
# 1  Falcon  2.0  370.0  Falcon   2    meat        both
# 2  Parrot  1.0   24.0  Parrot   1   seeds        both
# 3  Parrot  2.0   26.0  Parrot   2  fruits        both
# 4     NaN  NaN    NaN   Tiger   1    meat  right_only

# %% [markdown]
# ## Difference with Concat

# %%
df
# Out:
#    Animal  ID  Speed
# 0  Falcon   1    380
# 1  Falcon   2    370
# 2  Parrot   1     24
# 3  Parrot   2     26

# %%
df_food
# Out:
#    animal  id    food
# 0  Falcon   1  kibble
# 1  Falcon   2    meat
# 2  Parrot   1   seeds
# 3  Parrot   2  fruits
# 4   Tiger   1    meat

# %%
df1 = pd.concat([df, df_food])
df1
# Out:
#    Animal   ID  Speed  animal   id    food
# 0  Falcon  1.0  380.0     NaN  NaN     NaN
# 1  Falcon  2.0  370.0     NaN  NaN     NaN
# 2  Parrot  1.0   24.0     NaN  NaN     NaN
# 3  Parrot  2.0   26.0     NaN  NaN     NaN
# 0     NaN  NaN    NaN  Falcon  1.0  kibble
# 1     NaN  NaN    NaN  Falcon  2.0    meat
# 2     NaN  NaN    NaN  Parrot  1.0   seeds
# 3     NaN  NaN    NaN  Parrot  2.0  fruits
# 4     NaN  NaN    NaN   Tiger  1.0    meat

# %%
df1.loc[3, 'ID']
# Out:
# 3    2.0
# 3    NaN
# Name: ID, dtype: float64

# %%
df_food.columns
# Out:
# Index(['animal', 'id', 'food'], dtype='str')

# %%
df.columns
# Out:
# Index(['Animal', 'ID', 'Speed'], dtype='str')

# %%
df.columns = df_food.columns

# %%
df_food.columns
# Out:
# Index(['animal', 'id', 'food'], dtype='str')

# %%
df_ = pd.concat([df, df_food])
df_
# Out:
#    animal  id    food
# 0  Falcon   1     380
# 1  Falcon   2     370
# 2  Parrot   1      24
# 3  Parrot   2      26
# 0  Falcon   1  kibble
# 1  Falcon   2    meat
# 2  Parrot   1   seeds
# 3  Parrot   2  fruits
# 4   Tiger   1    meat

# %%
df_.loc[3, 'food']
# Out:
# 3        26
# 3    fruits
# Name: food, dtype: object

# %%
df_.dtypes
# Out:
# animal       str
# id         int64
# food      object
# dtype: object

# %% [markdown]
# ### Concatenating sideways ("merging" by position?)

# %%
df3 = pd.concat([df_food, df], axis = 1, verify_integrity=True)
df3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df3 = pd.concat([df_food, df], axis = 1, verify_integrity=True)
#       2 df3
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/reshape/concat.py:466, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     464 axis = 1 - bm_axis if is_frame else 0
#     465 names = names or getattr(keys, "names", None)
# --> 466 result = _get_result(
#     467     objs,
#     468     is_series,
#     469     bm_axis,
#     470     ignore_index,
#     471     intersect,
#     472     sort,
#     473     keys,
#     474     levels,
#     475     verify_integrity,
#     476     names,
#     477     axis,
#     478 )
#     480 if sort is lib.no_default:
#     481     if orig_axis == 0:
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/reshape/concat.py:630, in _get_result(objs, is_series, bm_axis, ignore_index, intersect, sort, keys, levels, verify_integrity, names, axis)
#     627 sample = cast("DataFrame", objs[0])
#     629 mgrs_indexers = []
# --> 630 result_axes = new_axes(
#     631     objs,
#     632     bm_axis,
#     633     intersect,
#     634     sort,
#     635     keys,
#     636     names,
#     637     axis,
#     638     levels,
#     639     verify_integrity,
#     640     ignore_index,
#     641 )
#     642 for obj in objs:
#     643     indexers = {}
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/reshape/concat.py:681, in new_axes(objs, bm_axis, intersect, sort, keys, names, axis, levels, verify_integrity, ignore_index)
#     667 def new_axes(
#     668     objs: list[Series | DataFrame],
#     669     bm_axis: AxisInt,
#    (...)    677     ignore_index: bool,
#     678 ) -> list[Index]:
#     679     """Return the new [index, column] result for concat."""
#     680     return [
# --> 681         _get_concat_axis_dataframe(
#     682             objs,
#     683             axis,
#     684             ignore_index,
#     685             keys,
#     686             names,
#     687             levels,
#     688             verify_integrity,
#     689         )
#     690         if i == bm_axis
#     691         else get_objs_combined_axis(
#     692             objs,
#     693             axis=objs[0]._get_block_manager_axis(i),
#     694             intersect=intersect,
#     695             sort=sort,
#     696         )
#     697         for i in range(2)
#     698     ]
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/reshape/concat.py:775, in _get_concat_axis_dataframe(objs, axis, ignore_index, keys, names, levels, verify_integrity)
#     773 if verify_integrity and not concat_axis.is_unique:
#     774     overlap = concat_axis[concat_axis.duplicated()].unique()
# --> 775     raise ValueError(f"Indexes have overlapping values: {overlap}")
#     777 return concat_axis
#
# ValueError: Indexes have overlapping values: Index(['animal', 'id', 'food'], dtype='str')

# %% [markdown]
# #### Disadvantages of Concat
#
# You may end up with duplicated column names - this will prevent you from some operations.

# %%
df3 = pd.concat([df_food, df], axis = 1)
df3[df3['animal'] == 'Parrot']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 2
#       1 df3 = pd.concat([df_food, df], axis = 1)
# ----> 2 df3[df3['animal'] == 'Parrot']
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4365, in DataFrame.__getitem__(self, key)
#    4363 # Do we have a (boolean) DataFrame?
#    4364 if isinstance(key, DataFrame):
# -> 4365     return self.where(key)
#    4367 # Do we have a (boolean) 1d indexer?
#    4368 if com.is_bool_indexer(key):
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/generic.py:10321, in NDFrame.where(self, cond, other, inplace, axis, level)
#   10314             warnings.warn(
#   10315                 _chained_assignment_method_msg,
#   10316                 ChainedAssignmentError,
#   10317                 stacklevel=2,
#   10318             )
#   10320 other = common.apply_if_callable(other, self)
# > 10321 return self._where(cond, other, inplace=inplace, axis=axis, level=level)
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/generic.py:10045, in NDFrame._where(self, cond, other, inplace, axis, level)
#   10042     cond = cond.astype(bool)
#   10044 cond = -cond if inplace else cond
# > 10045 cond = cond.reindex(self._info_axis, axis=self._info_axis_number)
#   10047 # try to align with other
#   10048 if isinstance(other, NDFrame):
#   10049     # align with me
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/frame.py:6078, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5843 def reindex(
#    5844     self,
#    5845     labels=None,
#    (...)   5855     tolerance=None,
#    5856 ) -> DataFrame:
#    5857     """
#    5858     Conform DataFrame to new index with optional filling logic.
#    5859
#    (...)   6076     See the :ref:`user guide <basics.reindexing>` for more.
#    6077     """
# -> 6078     return super().reindex(
#    6079         labels=labels,
#    6080         index=index,
#    6081         columns=columns,
#    6082         axis=axis,
#    6083         method=method,
#    6084         level=level,
#    6085         fill_value=fill_value,
#    6086         limit=limit,
#    6087         tolerance=tolerance,
#    6088         copy=copy,
#    6089     )
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/generic.py:5476, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5473     return self._reindex_multi(axes, fill_value)
#    5475 # perform the reindex on the axes
# -> 5476 return self._reindex_axes(
#    5477     axes, level, limit, tolerance, method, fill_value
#    5478 ).__finalize__(self, method="reindex")
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/generic.py:5498, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value)
#    5495     continue
#    5497 ax = self._get_axis(a)
# -> 5498 new_index, indexer = ax.reindex(
#    5499     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5500 )
#    5502 axis = self._get_axis_number(a)
#    5503 obj = obj._reindex_with_indexers(
#    5504     {axis: [new_index, indexer]},
#    5505     fill_value=fill_value,
#    5506     allow_dups=False,
#    5507 )
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:4253, in Index.reindex(self, target, method, level, limit, tolerance)
#    4250     raise ValueError("cannot handle a non-unique multi-index!")
#    4251 elif not self.is_unique:
#    4252     # GH#42568
# -> 4253     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4254 else:
#    4255     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels
