# %% [markdown]
# # UBC
# ## Programming in Python for DS
#
# January 23, 2023
#
# Instructor: Socorro Dominguez Vidana

# %%
import pandas as pd

# %% [markdown]
# ### Module 2
#
# Overview:
#
# - [] Show how to use `.loc` and `.iloc`
# - [] Demonstrate how to rename columns of a dataframe using .rename()
# - [] Create new or columns in a dataframe using .assign() notation.
# - [] Drop columns in a dataframe using .drop()
# - [] Use df[] notation to filter rows of a dataframe.
# - [] Calculate summary statistics on grouped objects using .groupby() and .agg().

# %%
data = {'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.],
                  'Min Speed': [120., 110., 5., 6.]}
data
# Out:
# {'Animal': ['Falcon', 'Falcon', 'Parrot', 'Parrot'],
#  'Max Speed': [380.0, 370.0, 24.0, 26.0],
#  'Min Speed': [120.0, 110.0, 5.0, 6.0]}

# %%
type(data)
# Out:
# dict

# %%
df = pd.DataFrame(data)
df
# Out:
#    Animal  Max Speed  Min Speed
# 0  Falcon      380.0      120.0
# 1  Falcon      370.0      110.0
# 2  Parrot       24.0        5.0
# 3  Parrot       26.0        6.0

# %%
df
# Out:
#    Animal  Max Speed  Min Speed
# 0  Falcon      380.0      120.0
# 1  Falcon      370.0      110.0
# 2  Parrot       24.0        5.0
# 3  Parrot       26.0        6.0

# %%
pd.DataFrame(df)
# Out:
#    Animal  Max Speed  Min Speed
# 0  Falcon      380.0      120.0
# 1  Falcon      370.0      110.0
# 2  Parrot       24.0        5.0
# 3  Parrot       26.0        6.0

# %%
df.describe()
# Out:
#         Max Speed   Min Speed
# count    4.000000    4.000000
# mean   200.000000   60.250000
# std    202.115479   63.352848
# min     24.000000    5.000000
# 25%     25.500000    5.750000
# 50%    198.000000   58.000000
# 75%    372.500000  112.500000
# max    380.000000  120.000000

# %% [markdown]
# ## `.loc`

# %% [markdown]
# Select rows and columns based on `label`
#
# The rule:
#
# `df.loc[:, start:end:step]` or `df.loc[:, [labels]]`

# %%
df.loc[:, 'Animal':'Max Speed']
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df.loc[:, ['Animal', 'Min Speed']]
# Out:
#    Animal  Min Speed
# 0  Falcon      120.0
# 1  Falcon      110.0
# 2  Parrot        5.0
# 3  Parrot        6.0

# %%
df.loc[2, ['Animal', 'Min Speed']]
# Out:
# Animal       Parrot
# Min Speed       5.0
# Name: 2, dtype: object

# %%
df.loc[0, 'Animal']
# Out:
# 'Falcon'

# %% [markdown]
# #### `.iloc`

# %% [markdown]
# Same as `loc` but works with index rather than label.

# %%
df.iloc[0, 0]
# Out:
# 'Falcon'

# %%
df.iloc[:,1]
# Out:
# 0    380.0
# 1    370.0
# 2     24.0
# 3     26.0
# Name: Max Speed, dtype: float64

# %%
df.loc[:, 'Max Speed']
# Out:
# 0    380.0
# 1    370.0
# 2     24.0
# 3     26.0
# Name: Max Speed, dtype: float64

# %% [markdown]
# #### `assign()`

# %% [markdown]
# with `.loc[]`

# %%
df.assign(speedx2 = df.loc[:, 'Max Speed']*2)
# Out:
#    Animal  Max Speed  Min Speed  speedx2
# 0  Falcon      380.0      120.0    760.0
# 1  Falcon      370.0      110.0    740.0
# 2  Parrot       24.0        5.0     48.0
# 3  Parrot       26.0        6.0     52.0

# %% [markdown]
# Keep in mind you are not saving anything here - yet.

# %%
df
# Out:
#    Animal  Max Speed  Min Speed
# 0  Falcon      380.0      120.0
# 1  Falcon      370.0      110.0
# 2  Parrot       24.0        5.0
# 3  Parrot       26.0        6.0

# %%
df  = df.assign(speedx2 = df.loc[:, 'Max Speed']*2)
df
# Out:
#    Animal  Max Speed  Min Speed  speedx2
# 0  Falcon      380.0      120.0    760.0
# 1  Falcon      370.0      110.0    740.0
# 2  Parrot       24.0        5.0     48.0
# 3  Parrot       26.0        6.0     52.0

# %%
df
# Out:
#    Animal  Max Speed  Min Speed  speedx2
# 0  Falcon      380.0      120.0    760.0
# 1  Falcon      370.0      110.0    740.0
# 2  Parrot       24.0        5.0     48.0
# 3  Parrot       26.0        6.0     52.0

# %% [markdown]
# without `.loc[]`

# %%
df.assign(speedx2 = df['Max Speed']*2)
df.assign(speedx2 = df.loc[:, 'Max Speed']*2)
# Out:
#    Animal  Max Speed  Min Speed  speedx2
# 0  Falcon      380.0      120.0    760.0
# 1  Falcon      370.0      110.0    740.0
# 2  Parrot       24.0        5.0     48.0
# 3  Parrot       26.0        6.0     52.0

# %%
df
# Out:
#    Animal  Max Speed  Min Speed  speedx2
# 0  Falcon      380.0      120.0    760.0
# 1  Falcon      370.0      110.0    740.0
# 2  Parrot       24.0        5.0     48.0
# 3  Parrot       26.0        6.0     52.0

# %% [markdown]
# without `.assign()`

# %%
df['new_col3'] = df['Max Speed']*2

# %%
df
# Out:
#    Animal  Max Speed  Min Speed  speedx2  new_col3
# 0  Falcon      380.0      120.0    760.0     760.0
# 1  Falcon      370.0      110.0    740.0     740.0
# 2  Parrot       24.0        5.0     48.0      48.0
# 3  Parrot       26.0        6.0     52.0      52.0

# %%
df['new_col3']
# Out:
# 0    760.0
# 1    740.0
# 2     48.0
# 3     52.0
# Name: new_col3, dtype: float64

# %% [markdown]
# #### `.drop()`

# %%
df.drop(columns = 'Max Speed')
# Out:
#    Animal  Min Speed  speedx2  new_col3
# 0  Falcon      120.0    760.0     760.0
# 1  Falcon      110.0    740.0     740.0
# 2  Parrot        5.0     48.0      48.0
# 3  Parrot        6.0     52.0      52.0

# %%
df
# Out:
#    Animal  Max Speed  Min Speed  speedx2  new_col3
# 0  Falcon      380.0      120.0    760.0     760.0
# 1  Falcon      370.0      110.0    740.0     740.0
# 2  Parrot       24.0        5.0     48.0      48.0
# 3  Parrot       26.0        6.0     52.0      52.0

# %%
df.drop(columns = ['Animal', 'Max Speed'])
# Out:
#    Min Speed  speedx2  new_col3
# 0      120.0    760.0     760.0
# 1      110.0    740.0     740.0
# 2        5.0     48.0      48.0
# 3        6.0     52.0      52.0

# %%
df
# Out:
#    Animal  Max Speed  Min Speed  speedx2  new_col3
# 0  Falcon      380.0      120.0    760.0     760.0
# 1  Falcon      370.0      110.0    740.0     740.0
# 2  Parrot       24.0        5.0     48.0      48.0
# 3  Parrot       26.0        6.0     52.0      52.0

# %%
df = df.drop(columns = 'new_col3')

# %%
df
# Out:
#    Animal  Max Speed  Min Speed  speedx2
# 0  Falcon      380.0      120.0    760.0
# 1  Falcon      370.0      110.0    740.0
# 2  Parrot       24.0        5.0     48.0
# 3  Parrot       26.0        6.0     52.0

# %%
df.rename(columns = {'Max Speed':'max_speed', 
                     'new_col':'speedx2'})
# Out:
#    Animal  max_speed  Min Speed  speedx2
# 0  Falcon      380.0      120.0    760.0
# 1  Falcon      370.0      110.0    740.0
# 2  Parrot       24.0        5.0     48.0
# 3  Parrot       26.0        6.0     52.0

# %%
df
# Out:
#    Animal  Max Speed  Min Speed  speedx2
# 0  Falcon      380.0      120.0    760.0
# 1  Falcon      370.0      110.0    740.0
# 2  Parrot       24.0        5.0     48.0
# 3  Parrot       26.0        6.0     52.0

# %%
df.shape
# Out:
# (4, 4)

# %%
df.columns = ['_animal', '_max_speed', '_min_speed', '_speed2']

# %%
df
# Out:
#   _animal  _max_speed  _min_speed  _speed2
# 0  Falcon       380.0       120.0    760.0
# 1  Falcon       370.0       110.0    740.0
# 2  Parrot        24.0         5.0     48.0
# 3  Parrot        26.0         6.0     52.0

# %% [markdown]
# #### `filter`

# %%
df
# Out:
#   _animal  _max_speed  _min_speed  _speed2
# 0  Falcon       380.0       120.0    760.0
# 1  Falcon       370.0       110.0    740.0
# 2  Parrot        24.0         5.0     48.0
# 3  Parrot        26.0         6.0     52.0

# %%
df['_max_speed'] > 300
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: _max_speed, dtype: bool

# %%
df[df['_max_speed'] > 300]
# Out:
#   _animal  _max_speed  _min_speed  _speed2
# 0  Falcon       380.0       120.0    760.0
# 1  Falcon       370.0       110.0    740.0

# %% [markdown]
# ```python
# df[(_____) & (_____)]
# ```

# %%
df[(df['_max_speed'] > 320) & (df['_max_speed'] < 380)]
# Out:
#   _animal  _max_speed  _min_speed  _speed2
# 1  Falcon       370.0       110.0    740.0

# %% [markdown]
# #### `.groupby()`

# %%
df
# Out:
#   _animal  _max_speed  _min_speed  _speed2
# 0  Falcon       380.0       120.0    760.0
# 1  Falcon       370.0       110.0    740.0
# 2  Parrot        24.0         5.0     48.0
# 3  Parrot        26.0         6.0     52.0

# %%
df.groupby('_animal')

# %% [markdown]
# **What does that even mean??**

# %% [markdown]
# ![](https://media1.giphy.com/media/FcuiZUneg1YRAu1lH2/giphy.gif?cid=ecf05e47t6tl4ppzchujy27worbrevfetpm299tixcfm7sk6&rid=giphy.gif&ct=g)

# %% [markdown]
# ![img](https://miro.medium.com/max/1206/0*5Zzcwe-rlxz-EQ_N)

# %%
df[df['_animal'] == 'Falcon']
# Out:
#   _animal  _max_speed  _min_speed  _speed2
# 0  Falcon       380.0       120.0    760.0
# 1  Falcon       370.0       110.0    740.0

# %%
df2 = df.groupby('_animal').sum()
df2
# Out:
#          _max_speed  _min_speed  _speed2
# _animal
# Falcon        750.0       230.0   1500.0
# Parrot         50.0        11.0    100.0

# %% [markdown]
# `reset_index()`

# %%
df.groupby('_animal').sum()
# Out:
#          _max_speed  _min_speed  _speed2
# _animal
# Falcon        750.0       230.0   1500.0
# Parrot         50.0        11.0    100.0

# %%
df.groupby('_animal').sum().reset_index()
# Out:
#   _animal  _max_speed  _min_speed  _speed2
# 0  Falcon       750.0       230.0   1500.0
# 1  Parrot        50.0        11.0    100.0

# %%
df.groupby('_animal', as_index=False).sum()
# Out:
#   _animal  _max_speed  _min_speed  _speed2
# 0  Falcon       750.0       230.0   1500.0
# 1  Parrot        50.0        11.0    100.0

# %%
df2.columns
# Out:
# Index(['_max_speed', '_min_speed', '_speed2'], dtype='object')

# %%
df2 = df2.reset_index()
df2
# Out:
#   _animal  _max_speed  _min_speed  _speed2
# 0  Falcon       750.0       230.0   1500.0
# 1  Parrot        50.0        11.0    100.0

# %%
df3 = df.groupby('_animal').agg({'_max_speed':['mean', 'sum']})
df3
# Out:
#         _max_speed
#               mean    sum
# _animal
# Falcon       375.0  750.0
# Parrot        25.0   50.0

# %%
df3.reset_index()
# Out:
#   _animal _max_speed
#                 mean    sum
# 0  Falcon      375.0  750.0
# 1  Parrot       25.0   50.0

# %%
df3[df3['_max_speed', 'mean'] > 300]
# Out:
#         _max_speed
#               mean    sum
# _animal
# Falcon       375.0  750.0

# %%
df.groupby('_animal').agg(['mean', 'sum']).loc[:,'_max_speed'].reset_index()
# Out:
#   _animal   mean    sum
# 0  Falcon  375.0  750.0
# 1  Parrot   25.0   50.0

# %% [markdown]
# Is there only **ONE** way of doing things?

# %% [markdown]
# ![](https://media2.giphy.com/media/ftqLysT45BJMagKFuk/giphy.gif?cid=ecf05e47zx1vugxxgh9hyet02mwendrr6tfopa20ysvst7pi&rid=giphy.gif&ct=g)

# %% [markdown]
# **The tests are a guide.**
#
# We cannot make very strict tests.
# - Inhibit your creativity.
#
# We cannot make very lenient tests.
# - Cannot test your output
#
# Tests are based on:
# - An ideal of best practices
# - Tidy data (more on this next week)
# - A bit of hand holding to make your life in future questions "easier"
# - Beginner friendly skills (if you are a pro, you might find them quite limiting)

# %% [markdown]
# **Disclaimer:**
# If you want the full mark, you need to pass the test.
#
# How?
#
# | NO | YES |
# | --- | --- |
# | ![](https://media3.giphy.com/media/9bXjoBk28pwnKLKoKb/giphy.gif?cid=ecf05e476d0x3f361cv2upqr8x6p1whtx5ggazdhrsoigmf0&rid=giphy.gif&ct=g) | ![](https://media4.giphy.com/media/anSiSGG5YaXeBn5gv4/giphy.gif?cid=ecf05e476d0x3f361cv2upqr8x6p1whtx5ggazdhrsoigmf0&rid=giphy.gif&ct=g)|
#
# Read the bottom part of the error messages, you might find them helpful.

# %% [markdown]
# #### Summary
#
# ##### What we did?
#
# - [x] Show how to use `.loc` and `.iloc`
# - [x] Demonstrate how to rename columns of a dataframe using .rename()
# - [x] Create new or columns in a dataframe using .assign() notation.
# - [x] Drop columns in a dataframe using .drop()
# - [x] Use df[] notation to filter rows of a dataframe.
# - [x] Calculate summary statistics on grouped objects using .groupby() and .agg().

# %% [markdown]
# ##### Extra (time allowing)
#
# How to change labels based on multiple conditions for different columns (Age in Titanic)

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})
df
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
import numpy as np

conditions = [
    ((df['Animal'] == 'Falcon') & (df['Max Speed'] < 350)),
    ((df['Animal'] == 'Falcon') & (df['Max Speed'] >= 350)),
    ((df['Animal'] == 'Parrot') & (df['Max Speed'] <= 300)),
    ((df['Animal'] == 'Parrot') & (df['Max Speed'] > 300))
    ]

# create a list of the values we want to assign for each condition
values = ['slow_falcon', 'fast_falcon', 'avg_parrot', 'vfast_parrot']

# create a new column and use np.select to assign values to it using our lists as arguments
df['class'] = np.select(conditions, values)

df
# Out:
#    Animal  Max Speed        class
# 0  Falcon      380.0  fast_falcon
# 1  Falcon      370.0  fast_falcon
# 2  Parrot       24.0   avg_parrot
# 3  Parrot       26.0   avg_parrot

# %%
df.loc[(df['Animal']=="Falcon")&(df['Max Speed']>375), "class"] = "super falcon"

# %%
df
# Out:
#    Animal  Max Speed         class
# 0  Falcon      380.0  super falcon
# 1  Falcon      370.0   fast_falcon
# 2  Parrot       24.0    avg_parrot
# 3  Parrot       26.0    avg_parrot
