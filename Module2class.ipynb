# %% [markdown]
# # UBC - KCDS
#
# ## PPDS
#
# ### Week 2
# Instructor: Socorro Dominguez-Vidana

# %% [markdown]
# Overview:
#
# - [] Show how to use `.loc` and `.iloc`
# - [] Demonstrate how to rename columns of a dataframe using `.rename()`
# - [] Create new or columns in a dataframe using `.assign()`.
# - [] Drop columns in a dataframe using `.drop()`
# - [] Use `df[]` to filter rows of a dataframe.
# - [] Calculate summary statistics on grouped objects using `.groupby()` and `.agg()`.
#
# Extras:
# - [] Conditional Value Filling
# - [] Plotting with Altair

# %% [markdown]
# ### Using `pd.DataFrame()`

# %%
import pandas as pd

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data = {'Animal': ['Falcon', 'Falcon', 'Parrot', 'Parrot'],
         'Food' : ['meat', 'meat', 'veggies', 'veggies'],
     'Max Speed': [380., 370., 24., 26.],
     'Min Speed': [120., 110., 5., 6.]}
data
# Out:
# {'Animal': ['Falcon', 'Falcon', 'Parrot', 'Parrot'],
#  'Food': ['meat', 'meat', 'veggies', 'veggies'],
#  'Max Speed': [380.0, 370.0, 24.0, 26.0],
#  'Min Speed': [120.0, 110.0, 5.0, 6.0]}

# %% [markdown]
# We use `pd.DataFrame()` when we want to convert a dictionary or other data structure into a `pd.DataFrame`.
#
# If we apply `pd.DataFrame()` to something that is already a `pd.DataFrame`, this is the equivalent of doing an **identity** operation (think of $1\times1$ or $1+0$)

# %%
df = pd.DataFrame(data)
df
# Out:
#    Animal     Food  Max Speed  Min Speed
# 0  Falcon     meat      380.0      120.0
# 1  Falcon     meat      370.0      110.0
# 2  Parrot  veggies       24.0        5.0
# 3  Parrot  veggies       26.0        6.0

# %%
df2 = pd.DataFrame(data)

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
pd.DataFrame(df)
# Out:
#    Animal     Food  Max Speed  Min Speed
# 0  Falcon     meat      380.0      120.0
# 1  Falcon     meat      370.0      110.0
# 2  Parrot  veggies       24.0        5.0
# 3  Parrot  veggies       26.0        6.0

# %%
pd.DataFrame(df.loc[:, 'Animal'])
# Out:
#    Animal
# 0  Falcon
# 1  Falcon
# 2  Parrot
# 3  Parrot

# %% [markdown]
# `Tip!` Remember that whenever you see a *new** function, look at the documentation. The easiest way (for me) is to look in the browser. Type something as "pandas DataFrame documentation" in the browser and usually the first entry will be your best friend.

# %% [markdown]
# #### Data Frames: Their Methods and Attributes
# ##### (The only thing you might need to know about OOP for now)
# ###### When to use `()` or not.

# %% [markdown]
# Before we can call an attribute or a method of an object, we need to know what type of object it is, that will determine what we can call. To learn about the type, we use the built-in function `type`

# %%
type(df)
# Out:
# pandas.DataFrame

# %% [markdown]
# - **Attributes** are just pieces of data that belong to an object — like a label stuck on it. Think of them as "what the object knows" or "what it has." You call them by using `.` and then the attribute.
#
# - Example:
#  If you have a data frame stored in the variable `df`, you can call its `shape` attribute by doing:
#
# `df` + `.` + `shape`

# %%
df
# Out:
#    Animal     Food  Max Speed  Min Speed
# 0  Falcon     meat      380.0      120.0
# 1  Falcon     meat      370.0      110.0
# 2  Parrot  veggies       24.0        5.0
# 3  Parrot  veggies       26.0        6.0

# %%
df2.shape
# Out:
# (4, 4)

# %%
df.columns
# Out:
# Index(['Animal', 'Food', 'Max Speed', 'Min Speed'], dtype='str')

# %% [markdown]
# - **Methods** are functions that belong to an object — things the object can do.
# For example, if we want a data frame object stored in `df` to describe itself, we call:
# `df` + `.` + `describe` + `()`

# %%
df.describe()
# Out:
#         Max Speed   Min Speed
# count    4.000000    4.000000
# mean   200.000000   60.250000
# std    202.115479   63.352848
# min     24.000000    5.000000
# 25%     25.500000    5.750000
# 50%    198.000000   58.000000
# 75%    372.500000  112.500000
# max    380.000000  120.000000

# %% [markdown]
# We will learn more about functions in Module 4, for now, the parenthesis `()` is a way of giving extra information of what we need. For example, the method describe can be passed with an empty `()`, then it just brings **by default** the statistics of the numeric variables. If we wanted to extract more information, ie, the qualitative variables as well, we can pass the argument `include = all`

# %%
df.describe(include = 'all')
# Out:
#         Animal  Food   Max Speed   Min Speed
# count        4     4    4.000000    4.000000
# unique       2     2         NaN         NaN
# top     Falcon  meat         NaN         NaN
# freq         2     2         NaN         NaN
# mean       NaN   NaN  200.000000   60.250000
# std        NaN   NaN  202.115479   63.352848
# min        NaN   NaN   24.000000    5.000000
# 25%        NaN   NaN   25.500000    5.750000
# 50%        NaN   NaN  198.000000   58.000000
# 75%        NaN   NaN  372.500000  112.500000
# max        NaN   NaN  380.000000  120.000000

# %% [markdown]
# ## The special indexing attributes `.iloc[]` and `.loc[]`
#
# What happens if I need to extract one value?

# %%
df_desc = df.describe()
df_desc
# Out:
#         Max Speed   Min Speed
# count    4.000000    4.000000
# mean   200.000000   60.250000
# std    202.115479   63.352848
# min     24.000000    5.000000
# 25%     25.500000    5.750000
# 50%    198.000000   58.000000
# 75%    372.500000  112.500000
# max    380.000000  120.000000

# %%
df_desc.loc['count', 'Max Speed']
# Out:
# np.float64(4.0)

# %% [markdown]
# `.loc[]` is a `pd.DataFrame` **attribute**.
# It looks a bit different, as it has the `[]` notation but that is because it is an indexer attribute, that means, we need to pass a `rows` and a `columns` location so that it can bring to us what values the data frame has at a specific position.

# %% [markdown]
# Select rows and columns based on `label`
#
# The rule:
#
# `df.loc[row]`
#
# `df.loc[*row*, start:end:step]` or `df.loc[*row*, [labels]]`
#
# `df.loc[:, 'column']`
#
# For all rows, use `:`

# %%
df
# Out:
#    Animal     Food  Max Speed  Min Speed
# 0  Falcon     meat      380.0      120.0
# 1  Falcon     meat      370.0      110.0
# 2  Parrot  veggies       24.0        5.0
# 3  Parrot  veggies       26.0        6.0

# %%
df.loc[0, 'Max Speed']
# Out:
# np.float64(380.0)

# %%
df.loc[[0,1], 'Animal':'Min Speed':2]
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0

# %%
df.loc[[3, 2], ['Animal', 'Max Speed']]
# Out:
#    Animal  Max Speed
# 3  Parrot       26.0
# 2  Parrot       24.0

# %%
df.loc[:, 'Animal']
# Out:
# 0    Falcon
# 1    Falcon
# 2    Parrot
# 3    Parrot
# Name: Animal, dtype: str

# %% [markdown]
# **NOTE** Look at the cell above, it looks different, not as a data frame. When we only have one row or one column of information, the data type is not a Data Frame any more, it is a `pandas.Series`. `pandas.Series` have their own attributes and methods.

# %% [markdown]
# #### `.iloc[]`

# %% [markdown]
# Same as `.loc[]` but works with numeric index rather than label.

# %%
df
# Out:
#    Animal     Food  Max Speed  Min Speed
# 0  Falcon     meat      380.0      120.0
# 1  Falcon     meat      370.0      110.0
# 2  Parrot  veggies       24.0        5.0
# 3  Parrot  veggies       26.0        6.0

# %%
df.iloc[[1, 2], [1, 2]]
# Out:
#       Food  Max Speed
# 1     meat      370.0
# 2  veggies       24.0

# %% [markdown]
# ##### Other attributes

# %% [markdown]
# Any `pandas.DataFrame` has:
# - Attributes:
#     - `.loc[]`
#     - `.iloc[]`
#     - `.shape`
#     - `.columns`
#     - `.dtypes`
#     - `.index`
#     - `.size`
#     - etc...
# - Methods:
#     - `.group_by()`
#     - `.sort_values()`
#     - `.rename()`
#     - `.assign()`
#     - etc...

# %%
df.dtypes
# Out:
# Animal           str
# Food             str
# Max Speed    float64
# Min Speed    float64
# dtype: object

# %% [markdown]
# ## Filtering

# %% [markdown]
# - `.loc[]` and `.iloc[]` can also be used as boolean indexers:

# %%
df
# Out:
#    Animal     Food  Max Speed  Min Speed
# 0  Falcon     meat      380.0      120.0
# 1  Falcon     meat      370.0      110.0
# 2  Parrot  veggies       24.0        5.0
# 3  Parrot  veggies       26.0        6.0

# %%
# We extract a mask of the rows where Animal is `Parrot`, a series of True and False values
df['Animal'] == 'Parrot'
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: Animal, dtype: bool

# %%
# We place exactly that same condition inside our `.loc[]` to retrieve the rows
df.loc[df['Animal'] == 'Parrot']
# Out:
#    Animal     Food  Max Speed  Min Speed
# 2  Parrot  veggies       24.0        5.0
# 3  Parrot  veggies       26.0        6.0

# %% [markdown]
# When we have multiple conditions, we can use:
#
# ```python
# df[(_____) & (_____)]
# ```

# %%
df2 = df.loc[(df['Max Speed'] > 320) & (df['Max Speed'] < 380)]
df2
# Out:
#    Animal  Food  Max Speed  Min Speed
# 1  Falcon  meat      370.0      110.0

# %% [markdown]
# #### Creating new columns or Overwriting columns with `.assign()`

# %% [markdown]
# 1. Option A: With `.loc[]`

# %%
df
# Out:
#    Animal     Food  Max Speed  Min Speed
# 0  Falcon     meat      380.0      120.0
# 1  Falcon     meat      370.0      110.0
# 2  Parrot  veggies       24.0        5.0
# 3  Parrot  veggies       26.0        6.0

# %% [markdown]
# Task: Let's create a new column that gives the difference between Max speed - Min Speed.

# %%
df.assign(speed_diff = df.loc[:, 'Max Speed']-df.loc[:, 'Min Speed'])
# Out:
#    Animal     Food  Max Speed  Min Speed  speed_diff
# 0  Falcon     meat      380.0      120.0       260.0
# 1  Falcon     meat      370.0      110.0       260.0
# 2  Parrot  veggies       24.0        5.0        19.0
# 3  Parrot  veggies       26.0        6.0        20.0

# %% [markdown]
# **Caution** If we call the df varaible again, you will see that your result is not being saved / stored.

# %%
df
# Out:
#    Animal     Food  Max Speed  Min Speed
# 0  Falcon     meat      380.0      120.0
# 1  Falcon     meat      370.0      110.0
# 2  Parrot  veggies       24.0        5.0
# 3  Parrot  veggies       26.0        6.0

# %% [markdown]
# In order to save the result, we need to overwrite the variable `df` or save it in a new variable, for notebook hygene, we simply overwrite our variable.

# %%
# Note that there is no output after running this cell
df = df.assign(speed_diff = df.loc[:, 'Max Speed']-df.loc[:, 'Min Speed'])

# %%
# Note tht when we call the variable, the new column is there.
df
# Out:
#    Animal     Food  Max Speed  Min Speed  speed_diff
# 0  Falcon     meat      380.0      120.0       260.0
# 1  Falcon     meat      370.0      110.0       260.0
# 2  Parrot  veggies       24.0        5.0        19.0
# 3  Parrot  veggies       26.0        6.0        20.0

# %% [markdown]
# 2. Option B: Without `.loc[]`
# Sometimes, we like to save some characters to keep the code more human readable.

# %%
df.loc[:,'Max Speed'] #df['Max Speed'] exactly the same
# Out:
# 0    380.0
# 1    370.0
# 2     24.0
# 3     26.0
# Name: Max Speed, dtype: float64

# %%
df['Max Speed']
# Out:
# 0    380.0
# 1    370.0
# 2     24.0
# 3     26.0
# Name: Max Speed, dtype: float64

# %%
df = df.assign(speed_diff2 = df['Max Speed']-df['Min Speed'])
df
# Out:
#    Animal     Food  Max Speed  Min Speed  speed_diff  speed_diff2
# 0  Falcon     meat      380.0      120.0       260.0        260.0
# 1  Falcon     meat      370.0      110.0       260.0        260.0
# 2  Parrot  veggies       24.0        5.0        19.0         19.0
# 3  Parrot  veggies       26.0        6.0        20.0         20.0

# %% [markdown]
# Cases where `assign` will not work:
#
# ```python
# df = df.assign(Diff Speed = df['Max Speed']-df['Min Speed'])
# ```
#
# You can still do:
# ```python
# df.assign(**{'Diff Speed': df['Max Speed'] - df['Min Speed']})
# ```
# But that's tricky and hard to remember... In this cases, do not use `.assign()`

# %%
df.assign(**{'Diff Speed' : df['Max Speed']-df['Min Speed']})
# Out:
#    Animal     Food  Max Speed  Min Speed  speed_diff  speed_diff2  Diff Speed
# 0  Falcon     meat      380.0      120.0       260.0        260.0       260.0
# 1  Falcon     meat      370.0      110.0       260.0        260.0       260.0
# 2  Parrot  veggies       24.0        5.0        19.0         19.0        19.0
# 3  Parrot  veggies       26.0        6.0        20.0         20.0        20.0

# %% [markdown]
# #### Creating new columns or Overwriting columns without `.assign()`

# %%
# On the left side of the `=`, you must have the df[col] of where you want to assign the new value. 
df['Diff Speed3'] = df['Max Speed'] - df['Min Speed']

# %%
df['Max Speed'] - df['Min Speed']
# Out:
# 0    260.0
# 1    260.0
# 2     19.0
# 3     20.0
# dtype: float64

# %% [markdown]
# Very common error:
#
# ```python
# df = df['Max Speed']-df['Min Speed']
# ```
# The above would overwrite the whole data frame to only one series, ie you will lose everything exept that new column.
#
# **be careful,** when not using `assign()`, make sure that you are only modifying one column:
#
# ```python
# df['Speed Diff'] = df['Max Speed']-df['Min Speed']
# ```

# %% [markdown]
# #### Why do I sometimes see double square brackets `[[]]`?
#
# The symbols `[]` have two uses:
# - list()
# - Indexing attributes
#
# Right now, we just saw the indexing attribute. But sometimes you may see the following:
# `df[['Animal', 'Food']]`
#
# Here, the outside `[]` is the indexer attribute we have been studying.
#
# The inside `[]` is a `list` and the main idea is that sometimes, you want to put a collection of columns together inside the `indexer` but if you just placed the items, pandas gets confused as to why we have so many arguments. To "cheat" the system, we place them inside a "box" or a "list". Don't worry too much about this now, but be aware of the difference.

# %%
pd.DataFrame(df['Animal'])
# Out:
#    Animal
# 0  Falcon
# 1  Falcon
# 2  Parrot
# 3  Parrot

# %%
# I create a list called cols
cols = ['Animal', 'Max Speed']
cols
# Out:
# ['Animal', 'Max Speed']

# %%
# I pass it inside my `.loc[]`
df.loc[:, cols]
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
# By substitution, this is the same as doing:
df.loc[:, ['Animal', 'Max Speed']]
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
# And we saw that sometimes we are lazy and save some characters, so we can summarize to:
df[['Animal', 'Max Speed']] #= df.loc[rows, columns]
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %% [markdown]
# #### `.drop()`
# We use this to get rid of columns we do not need anymore.

# %%
df
# Out:
#    Animal     Food  Max Speed  Min Speed  speed_diff  speed_diff2  Diff Speed3
# 0  Falcon     meat      380.0      120.0       260.0        260.0        260.0
# 1  Falcon     meat      370.0      110.0       260.0        260.0        260.0
# 2  Parrot  veggies       24.0        5.0        19.0         19.0         19.0
# 3  Parrot  veggies       26.0        6.0        20.0         20.0         20.0

# %%
df.drop(columns = 'Diff Speed3')
# Out:
#    Animal     Food  Max Speed  Min Speed  speed_diff  speed_diff2
# 0  Falcon     meat      380.0      120.0       260.0        260.0
# 1  Falcon     meat      370.0      110.0       260.0        260.0
# 2  Parrot  veggies       24.0        5.0        19.0         19.0
# 3  Parrot  veggies       26.0        6.0        20.0         20.0

# %%
df
# Out:
#    Animal     Food  Max Speed  Min Speed  speed_diff  speed_diff2  Diff Speed3
# 0  Falcon     meat      380.0      120.0       260.0        260.0        260.0
# 1  Falcon     meat      370.0      110.0       260.0        260.0        260.0
# 2  Parrot  veggies       24.0        5.0        19.0         19.0         19.0
# 3  Parrot  veggies       26.0        6.0        20.0         20.0         20.0

# %%
# We need to overwrite the variable to see changes.
df = df.drop(columns = 'Diff Speed3')

# %%
df
# Out:
#    Animal     Food  Max Speed  Min Speed  speed_diff  speed_diff2
# 0  Falcon     meat      380.0      120.0       260.0        260.0
# 1  Falcon     meat      370.0      110.0       260.0        260.0
# 2  Parrot  veggies       24.0        5.0        19.0         19.0
# 3  Parrot  veggies       26.0        6.0        20.0         20.0

# %% [markdown]
# As an alternative, instead of overwriting the variable, we can use the parameter `inplace = True`
# ```python
# df.drop(columns = 'Diff Speed3', inplace=True)
# ```

# %%
# Dropping more than one column
df.drop(columns = ['Max Speed', 'Min Speed'])
# Out:
#    Animal     Food  speed_diff  speed_diff2
# 0  Falcon     meat       260.0        260.0
# 1  Falcon     meat       260.0        260.0
# 2  Parrot  veggies        19.0         19.0
# 3  Parrot  veggies        20.0         20.0

# %% [markdown]
# ### Renaming with `.rename()`

# %%
df
# Out:
#    Animal     Food  Max Speed  Min Speed  speed_diff  speed_diff2
# 0  Falcon     meat      380.0      120.0       260.0        260.0
# 1  Falcon     meat      370.0      110.0       260.0        260.0
# 2  Parrot  veggies       24.0        5.0        19.0         19.0
# 3  Parrot  veggies       26.0        6.0        20.0         20.0

# %%
df = df.rename(columns = {'Max Speed':'max_speed', 
                          'Min Speed':'min_speed'})
df
# Out:
#    Animal     Food  max_speed  min_speed  speed_diff  speed_diff2
# 0  Falcon     meat      380.0      120.0       260.0        260.0
# 1  Falcon     meat      370.0      110.0       260.0        260.0
# 2  Parrot  veggies       24.0        5.0        19.0         19.0
# 3  Parrot  veggies       26.0        6.0        20.0         20.0

# %% [markdown]
# #### `.groupby()`

# %%
df
# Out:
#    Animal     Food  max_speed  min_speed  speed_diff  speed_diff2
# 0  Falcon     meat      380.0      120.0       260.0        260.0
# 1  Falcon     meat      370.0      110.0       260.0        260.0
# 2  Parrot  veggies       24.0        5.0        19.0         19.0
# 3  Parrot  veggies       26.0        6.0        20.0         20.0

# %%
group_df = df.groupby('Animal')
group_df

# %%
# It is a different data type, so it has different attributes and methods
type(group_df)
# Out:
# pandas.api.typing.DataFrameGroupBy

# %%
group_df.groups
# Out:
# {'Falcon': [0, 1], 'Parrot': [2, 3]}

# %%
group_df.get_group('Falcon')
# Out:
#    Animal  Food  max_speed  min_speed  speed_diff  speed_diff2
# 0  Falcon  meat      380.0      120.0       260.0        260.0
# 1  Falcon  meat      370.0      110.0       260.0        260.0

# %% [markdown]
# **What does that even mean??**

# %% [markdown]
# ![img](https://miro.medium.com/max/1206/0*5Zzcwe-rlxz-EQ_N)

# %%
df.groupby('Animal')

# %%
# This cannot be computed because 'Food' has words, so pandas cannot calculate the mean of words.
df.groupby('Animal').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 # This cannot be computed because 'Food' has words, so pandas cannot calculate the mean of words.
# ----> 2 df.groupby('Animal').mean()
#
# File ~/HT-Data/UBC/CourseFacilitatorMaterial/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
# ...

# %%
# But it can sum them - look that it concatenates them
df.groupby('Animal').sum()
# Out:
#                   Food  max_speed  min_speed  speed_diff  speed_diff2
# Animal
# Falcon        meatmeat      750.0      230.0       520.0        520.0
# Parrot  veggiesveggies       50.0       11.0        39.0         39.0

# %% [markdown]
# `.reset_index()`
# When we group by, the column we used to group, becomes an index, this makes it a bit harder to get the information if we still need it, so sometimes, we reset the index so that Animal is back to the columns section.

# %%
df.groupby('Animal').sum().reset_index()
# Out:
#    Animal            Food  max_speed  min_speed  speed_diff  speed_diff2
# 0  Falcon        meatmeat      750.0      230.0       520.0        520.0
# 1  Parrot  veggiesveggies       50.0       11.0        39.0         39.0

# %%
# If we want to compute different operations for different columns, we can use `agg` instead of the set of given functions:
# Note that we do not use `[]` when calling `'max'`
df.groupby('Animal').agg({'max_speed': 'max', 
                           'min_speed': 'max'}).reset_index()
# Out:
#    Animal  max_speed  min_speed
# 0  Falcon      380.0      120.0
# 1  Parrot       26.0        6.0

# %%
# If we want to compute multiple operations per different columns, we can use `[]` as a list
# Note that we pass 'sum' and 'mean' inside `[]`
df3 = df.groupby('Animal').agg({'max_speed':['sum', 'mean'], 
                                 'min_speed': ['max', 'min']}).reset_index()
df3
# Out:
#    Animal max_speed        min_speed
#                 sum   mean       max    min
# 0  Falcon     750.0  375.0     120.0  110.0
# 1  Parrot      50.0   25.0       6.0    5.0

# %% [markdown]
# Look at the two data frames above. Notice that when we pass things inside a `list []`, we create a double column index.
#
# Because of this, it is adviced that if you are only calling one operation, do not put it as a list.

# %% [markdown]
# Chaining sometimes is useful. But it can be stressful, the best way is do one step at a time until you are comfortable. Look at all the changes little by little, for now, it doesn't matter how many Jupyter cells you need:

# %%
df.groupby('Animal')

# %%
df.groupby('Animal').agg(['sum', 'count'])
# Out:
#                   Food       max_speed       min_speed       speed_diff        \
#                    sum count       sum count       sum count        sum count
# Animal
# Falcon        meatmeat     2     750.0     2     230.0     2      520.0     2
# Parrot  veggiesveggies     2      50.0     2      11.0     2       39.0     2
#
#        speed_diff2
#                sum count
# Animal
# Falcon       520.0     2
# Parrot        39.0     2

# %%
df.groupby('Animal').agg(['sum', 'count']).loc[:,'max_speed']
# Out:
#           sum  count
# Animal
# Falcon  750.0      2
# Parrot   50.0      2

# %%
df.groupby('Animal').agg(['sum', 'count']).loc[:,'max_speed'].reset_index()
# Out:
#    Animal    sum  count
# 0  Falcon  750.0      2
# 1  Parrot   50.0      2

# %% [markdown]
# #### A Fancier & More Efficient Way?

# %%
df.groupby('Animal').agg(
    sum = ('max_speed','mean'),
    count = ('max_speed','sum'),
).reset_index()
# Out:
#    Animal    sum  count
# 0  Falcon  375.0  750.0
# 1  Parrot   25.0   50.0

# %% [markdown]
# There exist multiple ways of doing the same thing; be creative and share as much as you wish in Piazza. Discuss interesting ways you found to get to a result.

# %% [markdown]
# **About Grading: The tests are *mostly* a guide.**
#
# We cannot make very strict tests.
# - Inhibit your creativity.
#
# We cannot make very lenient tests.
# - Cannot test your output
#
# Tests are based on:
# - An ideal of best practices
# - Tidy data (more on this next week)
# - A bit of hand holding to make your life in future questions "easier"
# - Beginner friendly skills (if you are a pro, you might find them quite limiting)
#
# However, if you get `Success`, that means you will get the point - as long as you have restarted your Kernel and verified that things run well from Top to Bottom.

# %% [markdown]
# **Disclaimer:**
# If you want the full mark, you need to pass the test.
#
# How?
#
# Read the bottom part of the error messages, you might find them helpful.

# %% [markdown]
# #### Summary
#
# ##### What we did?
#
# - [x] Show how to use `.loc` and `.iloc`
# - [x] Demonstrate how to rename columns of a dataframe using .rename()
# - [x] Create new or columns in a dataframe using .assign() notation.
# - [x] Drop columns in a dataframe using .drop()
# - [x] Use df[] notation to filter rows of a dataframe.
# - [x] Calculate summary statistics on grouped objects using .groupby() and .agg().

# %% [markdown]
# ### Appendix I
# #### Plotting with Altair
#
# **Altair** is a declarative statistical visualization library in Python that is built on the principles of the **[Grammar of Graphics](https://towardsdatascience.com/a-comprehensive-guide-to-the-grammar-of-graphics-for-effective-visualization-of-multi-dimensional-1f92b4ed4149)**. Here is a brief overview of its logic:
#
# *Basic Components*
# - Data: The dataset you want to visualize, typically provided as a Pandas DataFrame.
# - Mark: The geometric shape used to represent data points (e.g., bar, point, line).
# - Encoding: The mapping of data attributes (columns) to visual properties (e.g., x-axis, y-axis, color, size).
#
# **Steps to Create a Visualization**

# %%
df
# Out:
#    Animal     Food  max_speed  min_speed  speed_diff  speed_diff2
# 0  Falcon     meat      380.0      120.0       260.0        260.0
# 1  Falcon     meat      370.0      110.0       260.0        260.0
# 2  Parrot  veggies       24.0        5.0        19.0         19.0
# 3  Parrot  veggies       26.0        6.0        20.0         20.0

# %%
#Import Altair and load your data:
import altair as alt

df = df.groupby('Animal').agg(
    mean = ('max_speed','mean'),
    count = ('max_speed','sum'),
).reset_index()
df
# Out:
#    Animal   mean  count
# 0  Falcon  375.0  750.0
# 1  Parrot   25.0   50.0

# %%
# Initialize a Chart: Create a basic chart object by passing the data.
chart = alt.Chart(df)

# %%
#chart

# %%
# Add a Mark: Specify the type of mark to use.
chart = chart.mark_bar()

# %%
# Add encodings
chart = chart.encode(
    x='Animal:O',  # O for ordinal
    y='mean:Q'      # Q for quantitative
)

# %%
# Render the Chart: Display the chart.
# You can also do: chart.display()
chart
# Out:
# alt.Chart(...)

# %%
df
# Out:
#    Animal   mean  count
# 0  Falcon  375.0  750.0
# 1  Parrot   25.0   50.0

# %% [markdown]
# In one chunk of code:

# %%
import altair as alt

# %%
chart = alt.Chart(df).mark_bar().encode(
    x='Animal:O',  # O for ordinal
    y='mean:Q'      # Q for quantitative
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# Try different marks: `.mark_line()`, `.mark_point()`, `.mark_tick()`
