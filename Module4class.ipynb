# %% [markdown]
# # UBC - KCDS
#
# ## PPDS
#
# ### Week 4
# Instructor: Socorro Dominguez-Vidana

# %% [markdown]
# ## Overview
#
# - [] Compare and contrast Python's key **data types**.
# - [] Compare and contrast Python's key **data structures**.
# - [] Use Python to determine the type and structure of an object.
# - [] Demonstrate how to create data structures and convert them to another.
# - [] Identify which operations can be applied to different data types and columns dtypes.

# %% [markdown]
# ### Python Built-in Datatypes
#
# - Integers
# ```python
# 5
# ```
#
# - Floats
# ```python
# 5.0
# ```
#
# - Booleans (capitalized, no `'` or `"` needed)
# ```python
# True
# False
# ```
#
# - Strings (ordered, immutable)
# ```python
# "Hello"
# ```

# %% [markdown]
# To see what data type an element is, use the command `type()`:
#
# ```python
# type(5)
# ```
#
# ```output
# int
# ```

# %%
var = "5.0"
type(var)
# Out:
# str

# %% [markdown]
# #### Casting Datatypes
# Sometimes, we need to use information that comes in a different data type from what we need...

# %%
2+5
# Out:
# 7

# %%
'2' + '5'
# Out:
# '25'

# %%
[4,5] + [6,1]
# Out:
# [4, 5, 6, 1]

# %%
float('5.0')
# Out:
# 5.0

# %%
float('five')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 float('five')
#
# ValueError: could not convert string to float: 'five'

# %%
x = 4

# %%
"I bought " + (x) + " apples"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 "I bought " + (x) + " apples"
#
# TypeError: can only concatenate str (not "int") to str

# %%
"I bought " + str(x) + " apples"
# Out:
# 'I bought 4 apples'

# %%
f"I bought {x} apples"
# Out:
# 'I bought 4 apples'

# %%
type('5')
# Out:
# str

# %%
type(int('5'))
# Out:
# int

# %% [markdown]
# #### Strings
# ##### Characteristics
#
# - `'` `"` up to your preference.
#     - However, if you use `'` as an apostrophe, then, you need to use `"`
# - Ordered
# - Immutable

# %%
"Hello!"
# Out:
# 'Hello!'

# %%
'Hello!'
# Out:
# 'Hello!'

# %%
'She said, "hello!"'
# Out:
# 'She said, "hello!"'

# %%
sentence = "I bought 2.5 lbs of apples."

# %%
type(sentence)
# Out:
# str

# %% [markdown]
# ##### Order allows access to different index positions.

# %%
sentence[5]
# Out:
# 'g'

# %%
sentence[0:1000:3]
# Out:
# 'Ioh2 sfpe'

# %% [markdown]
# ##### Immutable
# It means that we cannot change/modify parts of it

# %%
sentence[0] = 'U'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sentence[0] = 'U'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ##### Methods

# %%
sentence
# Out:
# 'I bought 2.5 lbs of apples.'

# %%
sentence.split('.')
# Out:
# ['I bought 2', '5 lbs of apples', '']

# %%
sentence.title()
# Out:
# 'I Bought 2.5 Lbs Of Apples.'

# %%
sentence.upper()
# Out:
# 'I BOUGHT 2.5 LBS OF APPLES.'

# %%
sentence.lower()
# Out:
# 'i bought 2.5 lbs of apples.'

# %%
sentence
# Out:
# 'I bought 2.5 lbs of apples.'

# %%
sentence = sentence.lower()
sentence
# Out:
# 'i bought 2.5 lbs of apples.'

# %%
len(sentence)
# Out:
# 27

# %% [markdown]
# `.upper()`/'`.lower()` can be used when we are working with codes (such as ISBN or DOIs), headers, or commands.

# %% [markdown]
# ## Data Structures

# %% [markdown]
# #### Lists
#
# - Ordered sequence of items
# - `[` and `]`
# - Different data types can be stored

# %% [markdown]
# ```python
# df.groupby(by=['Col1', 'Col2']).mean()
# ```
#
# ##### Methods

# %%
a_string = "Hello world! How are you?"

# %%
a_list = a_string.split()
a_list
# Out:
# ['Hello', 'world!', 'How', 'are', 'you?']

# %%
a_new_list = []
for word in a_list:
    a_new_list.append(word)
    print(word)
    print(a_new_list)
# Out:
# Hello
# ['Hello']
# world!
# ['Hello', 'world!']
# How
# ['Hello', 'world!', 'How']
# are
# ['Hello', 'world!', 'How', 'are']
# you?
# ['Hello', 'world!', 'How', 'are', 'you?']

# %%
a_new_list
# Out:
# ['Hello', 'world!', 'How', 'are', 'you?']

# %%
b = print("hello")
b
# Out:
# hello

# %%
b

# %%
type(b)
# Out:
# NoneType

# %%
a_new_list
# Out:
# ['Hello', 'world!', 'How', 'are', 'you?']

# %%
a_new_list.append("hello")

# %%
type(a_new_list)
# Out:
# list

# %%
a_new_list
# Out:
# ['Hello', 'world!', 'How', 'are', 'you?', 'hello']

# %%
a_new_list.append(["Good", "to"])

# %%
a_new_list[6]
# Out:
# ['Good', 'to']

# %%
a_new_list + ["goodbye", "It", "was", "good!"]
# Out:
# ['Hello',
#  'world!',
#  'How',
#  'are',
#  'you?',
#  'hello',
#  ['Good', 'to'],
#  'goodbye',
#  'It',
#  'was',
#  'good!']

# %%
a_new_ = a_new_list + ["hello"] # you can add more elements to the 2nd list

# %%
a_new_list.append("Good", "hello")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 a_new_list.append("Good", "hello")
#
# TypeError: list.append() takes exactly one argument (2 given)

# %% [markdown]
# `.extend()`

# %%
a_new_list.extend(["Good", "hello"])
a_new_list
# Out:
# ['Hello',
#  'world!',
#  'How',
#  'are',
#  'you?',
#  'hello',
#  ['Good', 'to'],
#  'Good',
#  'hello']

# %%
a_new_list
# Out:
# ['Hello',
#  'world!',
#  'How',
#  'are',
#  'you?',
#  'hello',
#  ['Good', 'to'],
#  'Good',
#  'hello']

# %% [markdown]
# **Never do**
# ```python
# my_list = my_list.append(4)
# ```
# This will lead your list to end up being `None`
#
# **Note** If you rerun the code cell multiple times, the value will be appended multiple times.

# %%
my_list = [(3,5), (5, 4), (3, 4), True, "Hello"]
my_list
# Out:
# [(3, 5), (5, 4), (3, 4), True, 'Hello']

# %% [markdown]
# We can slice them / Access their elements

# %%
my_list[0]
# Out:
# (3, 5)

# %%
my_list[0][0]
# Out:
# 3

# %%
my_list[1:4:2]
# Out:
# [(5, 4), True]

# %% [markdown]
# ##### List Comprehension
#
# We can manipulate a whole list using list comprehension:

# %%
# Add 5 to each element of the following list
new_list = [0,3,4,5]
other_new_list = []
for i in new_list:
    x = i+5
    other_new_list.append(x)
other_new_list
# Out:
# [5, 8, 9, 10]

# %%
# Using list comprehension 
other_new_list2 = [b+5 for b in new_list]

other_new_list2
# Out:
# [5, 8, 9, 10]

# %% [markdown]
# #### Tuples
# Tuples are a data structure very similar to lists but with two main differences:
#
# - Represented with parentheses `(` `)`
# - Immutable

# %%
my_tuple = ('I', None,  'do', 1, False)
my_tuple
# Out:
# ('I', None, 'do', 1, False)

# %%
my_list = ['I', None,  'do', 1, False]
my_list
# Out:
# ['I', None, 'do', 1, False]

# %%
my_list[0] = 'You'
my_list
# Out:
# ['You', None, 'do', 1, False]

# %%
my_tuple[0] = 'You'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 my_tuple[0] = 'You'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### Sets
#
# - Unordered
# - The values contained are unique - meaning there are no duplicate entries.
# - Sets are made with curly brackets `{`, `}`.

# %%
my_set = {2, 1.0, "A", 1.0, "a"}
my_set
# Out:
# {1.0, 2, 'A', 'a'}

# %%
1 in my_set
# Out:
# True

# %%
my_set[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 my_set[2]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# **You can edit them - you can remove elements from them**

# %%
my_set.remove('A')
my_set
# Out:
# {1.0, 2, 'a'}

# %%
# You can remove the element just once
if "A" in my_set:
    my_set.remove('A')
my_set
# Out:
# {1.0, 2, 'a'}

# %%
my_set
# Out:
# {1.0, 2, 'a'}

# %% [markdown]
# ### Dictionaries
# - Represented by `{ key : value, key2: value2}`
# - Pairs of keys and corresponding values
# - `keys` must not be repeated (otherwise only one will be considered)
# - If the length of the values is the same, you can create a `pandas.DataFrame`.

# %%
data = {'Col1' : [2, 3, 4, 5, 5],
        'Col2' : [3, 3, 5, None, None]}
data
# Out:
# {'Col1': [2, 3, 4, 5, 5], 'Col2': [3, 3, 5, None, None]}

# %%
import pandas as pd
pd.DataFrame(data)
# Out:
#    Col1  Col2
# 0     2   3.0
# 1     3   3.0
# 2     4   5.0
# 3     5   NaN
# 4     5   NaN

# %%
pet = {
    "name": "Biscuit",
    "animal": "hamster",
    "hobby": "escaping",
    "age": 1
}

# %%
pet.keys()
# Out:
# dict_keys(['name', 'animal', 'hobby', 'age'])

# %%
for k in pet.keys():
    print(k)
# Out:
# name
# animal
# hobby
# age

# %%
pet.values()
# Out:
# dict_values(['Biscuit', 'hamster', 'escaping', 1])

# %%
pet.items()
# Out:
# dict_items([('name', 'Biscuit'), ('animal', 'hamster'), ('hobby', 'escaping'), ('age', 1)])

# %% [markdown]
# ### Accessing Values via the Keys

# %%
pet = {
    "name": "Biscuit",
    "animal": "hamster",
    "hobby": "escaping",
    "age": 1
}

# %%
pet2 = {
    "name": "Simba",
    "animal": "cat",
    "hobby": "chasing Biscuit",
    "age": 2,
    "nemesis": "vacuum cleaner"
}

# %%
pet['name']
# Out:
# 'Biscuit'

# %%
pet.get('name', 'missing')
# Out:
# 'Biscuit'

# %%
pet2.get('nemesis', 'missing')
# Out:
# 'vacuum cleaner'

# %%
pet.get('nemesis', 'placeholder')
# Out:
# 'placeholder'

# %%
key = 'name'
pet[key] + " & "+  pet2[key]
# Out:
# 'Biscuit & Simba'

# %% [markdown]
# #### Quiz Questions?

# %% [markdown]
# - 18 / 19 questions
# - 60 minutes
# - Once you start, you must finish.

# %% [markdown]
# ##### Kind of questions:
#
# - Multiple Choice:
#
# ```
# Which of the following statements are true:
#     - [] Data frames belong to the numpy library.
#     - [] Some attributes of Data frames are `.loc`, `.shape`, and `.columns`
#     - [] ...
#     - [] ...
# ```
# <br>
# <br>
# <br>
#
# - Multiple choice - Fill in the blanks:
# ```
# df.______(by='Colour').____()
# ```
#     Choose the correct words in each blank space:
#
# A) group_by , sum
# B) groupby, count
# C) sort_by, sum
# D) sort_by, count

# %% [markdown]
# - Fill in the blanks - Complete the following statement:
#
# ```
# df.______(by = 'Colour').sum()
# ```
# Expected answer:
# _group_by_
#
# - Match with definitions / explanations:
#
# ```
# List [  C ]
#
# Tuple [ B ]
#
# Dictionary [ A ]
# ```
#
# ```
# A. Key-value relationship
#
# B. Ordered elements in inmutable structure
#
# C. Ordered elements, starts with [ and ends with ]
# ```
